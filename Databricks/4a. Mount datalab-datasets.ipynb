# %% [markdown]
# d # Mount `datalab-datasets`

# %% [markdown]
# ![alt](http://www.scatter.com/images/DataLab_logo.jpg)

# %% [markdown]
# After running the following two code cells， your Databricks account will have access to a collection of datasets made available by the Data Lab. This includes datasets for the course MA705/MA402A. These files/sub-directories will be (once you run these two commands) in the directory `/dbfs/mnt/datlab-datasets`.
#
# These two cells only need to be run once. If you run them a second time the second command will return the exception `Directory already mounted`. This is OK and is not really an error.
#
# Go ahead and run the two cells below. Note that this is Scala code, not R code.

# %%
# %scala
val ACCESS_KEY = "AKIAJ6BO6D7ODSLYIEHA"
val SECRET_KEY = "G45nc02RvLgDm5Ob+dYCgK5yvHtjWOD3By3TnsNN"
val ENCODED_SECRET_KEY = SECRET_KEY.replace("/", "%2F")
val AWS_BUCKET_NAME = "datalab-datasets"
val MOUNT_NAME      = "datalab-datasets"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ACCESS_KEY: String = AKIAJ6BO6D7ODSLYIEHA
# SECRET_KEY: String = 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
# ENCODED_SECRET_KEY: String = G45nc02RvLgDm5Ob+dYCgK5yvHtjWOD3By3TnsNN
# AWS_BUCKET_NAME: String = datalab-datasets
# MOUNT_NAME: String = datalab-datasets
# </div>

# %%
# %scala 
dbutils.fs.mount(s"s3a://$ACCESS_KEY:$ENCODED_SECRET_KEY@$AWS_BUCKET_NAME", 
                 s"/mnt/$MOUNT_NAME")

# %% [markdown]
# Check that the above command worked as expected (and look for the sub-directories we expect.)

# %%
# %sh ls /dbfs/mnt/datalab-datasets/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">538_data
# aas2e
# cisi
# college-scorecard
# condorDemo
# file-samples
# JSON
# kiva
# ma705
# metar
# per_diem
# psa
# texts
# tmp
# wdi
# yelp
# zillow
# </div>

# %% [markdown]
# You should see directories called `JSON` and `texts`.

# %% [markdown]
# Next: open the `Contents data-lab` notebook to explore the contents of `'/dbfs/mnt/datalab-datasets`.

# %% [markdown]
# __The End__

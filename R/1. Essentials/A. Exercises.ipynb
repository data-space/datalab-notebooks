# %% [markdown]
# # Exercises for R Essentials

# %% [markdown]
# ## Contents
# 1. Data Lab notebooks
# 2. JSON data format
# 3.

# %% [markdown]
# ## 1. Data Lab notebooks
#
# The techniques to be used in these exercises can be found in the notebook links listed below.
# In addition reference links are provided for each exercise.
# - [Values & Variables](https://bentley.cloud.databricks.com/#notebook/92262/command/92263)
# - [Atomic Vectors](https://bentley.cloud.databricks.com/#notebook/92332/command/269838)
# - [Augmented Vectors](https://bentley.cloud.databricks.com/#notebook/92332)
# - [Matrices](https://bentley.cloud.databricks.com/#notebook/481925/command/481926)
# - [Functions](https://bentley.cloud.databricks.com/#notebook/92514)
# - [Lists](https://bentley.cloud.databricks.com/#notebook/92164/command/92165)
# - [Apply family](https://bentley.cloud.databricks.com/#notebook/92211/command/92212)
#
#
# All links are to notebooks on the Bentley Databricks cluster. Links to GitHub will be provided as soon as possible.

# %% [markdown]
# ## 2. Exercises

# %% [markdown]
# __Exercise:__ define three functions:
# - `plus3` which has a single input parameter and returns the value of that parameter plus `3`; for instance `plus3(5)` returns `8`
# - `times2` which has a single input parameter and returns the value of that parameter times `2`; for instance `times2(5)` returns `10`
# - `times` which has a two input parameters and returns their product; for instance `times(4,5)` returns `20`
#
# Reference: [Functions](https://bentley.cloud.databricks.com/#notebook/92514)

# %% [markdown]
# #### JSON data format

# %% [markdown]
# ##### Construct a JSON object
# __Exercise:__ Create JSON data (which is a string) that contains (fake) contact info for three people.
# - Store this string in the variable `group_json_string` below.
# - In the following exercises this data will create a list and each element of the list will be a named list.
#
# Reference: [JSON Data Format](https://bentley.cloud.databricks.com/#notebook/92086)

# %%
# %r
group_json_string = ''

# %%
# %r

# %% [markdown]
# ##### Create a list from the JSON contact data
# __Exercise:__ create an R list `group_list` using the JSON data, stored in `group_json_string`, from the previous exercise.
# - Use the `simplifyVector` parameter in your call to the `fromJSON` function
#
# Reference: [JSON Data Format](https://bentley.cloud.databricks.com/#notebook/92086)

# %%
# %r

# %% [markdown]
# ##### Create a dataframe from the JSON contact data
#
# __Exercise:__ create an R dataframe using the JSON data, stored in `group_json_string`, from the previous exercise.
#
# The work here is to load the proper libraries and to call the `fromJSON` function with the above variable.
# Use the `simplifyVector` parameter in your call to the `fromJSON` function.
#
# Reference: [JSON to Dataframes](https://bentley.cloud.databricks.com/#notebook/92024/command/92025)

# %%
# %r

# %% [markdown]
# Using the list you created above:
# - display a list of the values in the name field (only) for every item of the list. (Use an apply function for this.)

# %%
# %r

# %% [markdown]
# #### R lists & apply functions

# %% [markdown]
# __Exercise:__ Using this file: `/dbfs/mnt/datalab-datasets/file-samples/one_list.json`:
# - Create a vector or list of the values from the `quantity` field
# - Do so by reading the contents of this JSON file into an R list and using an apply function
#
# Reference:- [JSON to Dataframes](https://bentley.cloud.databricks.com/#notebook/92024/command/92025),
# [Apply Family](https://bentley.cloud.databricks.com/#notebook/92211/command/92212)

# %% [markdown]
# __Exercise:__ Using this file: `/dbfs/mnt/datalab-datasets/file-samples/one_list.json`:
# - Create a vector or list of the values from the `quantity` field
# - Do so by reading the contents of this JSON file directly into an R dataframe and retrieving a column from the dataframe
#
# Reference:- [JSON to Dataframes](https://bentley.cloud.databricks.com/#notebook/92024/command/92025),
# [Apply Family](https://bentley.cloud.databricks.com/#notebook/92211/command/92212)

# %% [markdown]
# __The End__

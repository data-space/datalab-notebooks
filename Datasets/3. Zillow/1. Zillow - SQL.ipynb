# %% [markdown]
# # Dataset: Zillow

# %% [markdown]
# ## Contents
# 1. Setup

# %% [markdown]
# ## 1. Setup

# %%
# %sh ls -hot /dbfs/mnt/datalab-datasets/zillow/*

# %%
# %r
properties_filepath = '/dbfs/mnt/datalab-datasets/zillow/properties_2016.csv'

# %%
# %python
properties_filepath = '/dbfs/mnt/datalab-datasets/zillow/properties_2016.csv'

# %% [markdown]
# ## 3. Read using SQL

# %%
drop table if exists zillow_properties

# %%
create temporary table zillow_properties 
using CSV 
options(path='/mnt/datalab-datasets/zillow/properties_2016.csv', 
        header=TRUE)

# %%
select *
from zillow_properties
limit 3

# %% [markdown]
# __The End__

# %% [markdown]
# # Read Per Diem Dataset with R

# %% [markdown]
# ## Introduction
# This notebook imports the Per Diem dataset. This entails:
# 2. Reading the datafile (into a dataframe)
# 3. Checking the datatypes (of each column in the dataframe)
# 4. Setting these datatypes (if they were not initially read correctly)
#
# The sections of this notebook (listed below, except the Setup section) correspond to each step.
# Note that the columns of the diamonds dataset are all initially read correctly.
# Other notebooks require more work to set the column datatypes correctly.

# %% [markdown]
# ## Contents
# 1. Setup
# 2. Read datafile
# 3. Check column types
# 4. Set column types

# %% [markdown]
# ## 1. Setup

# %%
# %sh ls /dbfs/mnt/datalab-datasets/per_diem/*.xls
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/dbfs/mnt/datalab-datasets/per_diem/April2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/April2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/August2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/August2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/December2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/February2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/February2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/January2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/January2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/July2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/July2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/June2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/June2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/March2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/March2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/May2018PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/November2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/October2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/September2017PD.xls
# /dbfs/mnt/datalab-datasets/per_diem/September2018PD.xls
# </div>

# %%
# %r
per_diem_filepath = '/dbfs/mnt/datalab-datasets/per_diem/August2017PD.xls'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'></pre>

# %%
# %python
per_diem_filepath = '/dbfs/mnt/datalab-datasets/per_diem/August2017PD.xls'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 3. Read dataset using `read_csv` from `readr` (R)

# %% [markdown]
# The code below uses the `read_excel` function from the `readxl` library.
# For details on the function, see:
# - https://readr.tidyverse.org/reference/read_delim.html
#
# The code also uses the pipe operator from the `magrittr` library.
# For details on this operator, see:
# - `/Data Lab notebooks/R/Essentials/Pipes`

# %%
# %r 
library(magrittr)
library(readxl)
per_diem_filepath %>%
read_excel() %>%
str()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'>Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	1109 obs. of  11 variables:
#  $ Country            : chr  "AFGHANISTAN" "AFGHANISTAN" "ALBANIA" "ALBANIA" ...
#  $ Location           : chr  "[Other]" "Kabul" "[Other]" "Tirana" ...
#  $ Season Code        : chr  "S1" "S1" "S1" "S1" ...
#  $ Season Start Date  : POSIXct, format: "2017-01-01" "2017-01-01" ...
#  $ Season End Date    : POSIXct, format: "2017-12-31" "2017-12-31" ...
#  $ Lodging            : num  0 0 82 190 192 188 209 405 405 279 ...
#  $ Meals & Incidentals: num  15 33 39 90 112 78 123 170 170 161 ...
#  $ Per Diem           : num  15 33 121 280 304 266 332 575 575 440 ...
#  $ Effective Date     : POSIXct, format: "2003-08-01" "2016-07-01" ...
#  $ Footnote Reference : chr  "19,2" "19,2" NA NA ...
#  $ Location Code      : num  11804 10323 11908 10104 11805 ...</pre>

# %% [markdown]
# __The End__

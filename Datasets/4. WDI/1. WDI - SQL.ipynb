# %% [markdown]
# # World Development Indicators Dataset

# %% [markdown]
# ## Contents
# 1. Setup

# %% [markdown]
# ## 1. Setup

# %%
# %python
wdi_basedir = '/dbfs/mnt/datalab-datasets/ma705/WDI_csv/'

# %%
# %r
wdi_basedir = '/dbfs/mnt/datalab-datasets/ma705/WDI_csv/'

# %% [markdown]
# ### `WDI` using SQL

# %%
# %sql
drop table if exists wdi

# %%
# %sql
create temporary table wdi
using CSV 
options(path="/mnt/datalab-datasets/ma705/WDI_csv//WDIData.csv", 
        header=TRUE)

# %%
# %sql
select *
from wdi
limit 3

# %% [markdown]
# __The End__

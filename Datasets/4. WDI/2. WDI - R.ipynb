# %% [markdown]
# # World Development Indicators Dataset

# %% [markdown]
# ## Contents
# 1. Setup

# %% [markdown]
# ## 1. Setup

# %%
# %sh ls -hot /dbfs/mnt/datalab-datasets/ma705/WDI_csv/*
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-rw-r--r-- 1 root 180M Aug 26  2017 /dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDIData.csv
# -rw-r--r-- 1 root 3.5M Aug 25  2017 /dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDISeries.csv
# -rw-r--r-- 1 root 790K Aug 25  2017 /dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDICountry-Series.csv
# -rw-r--r-- 1 root  43M Aug 25  2017 /dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDIFootNote.csv
# -rw-r--r-- 1 root 144K Aug 25  2017 /dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDICountry.csv
# -rw-r--r-- 1 root  36K Aug 25  2017 /dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDISeries-Time.csv
# </div>

# %%
# %python
wdi_filepath = '/dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDIData.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %r
wdi_filepath = '/dbfs/mnt/datalab-datasets/ma705/WDI_csv/WDIData.csv'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'></pre>

# %% [markdown]
# ### `iris` using `read_csv` from the `readr` library (R)

# %% [markdown]
# - https://readr.tidyverse.org/reference/read_delim.html

# %%
# %r 
library(magrittr)
library(readr)
wdi_filepath %>%
read_csv() %>%
{.} -> wdi_rdf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p">Parsed with column specification:
# cols(
#   .default = col_double(),
#   `Country Name` = col_character(),
#   `Country Code` = col_character(),
#   `Indicator Name` = col_character(),
#   `Indicator Code` = col_character(),
#   X62 = col_character()
# )
# See spec(...) for full column specifications.
# </pre><pre style = 'font-size:10pt'></pre>

# %%
# %r 
library(magrittr)
wdi_rdf %>%
  str
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <pre style="font-size:10p"></pre><pre style = 'font-size:10pt'>Classes ‘tbl_df’, ‘tbl’ and 'data.frame':	397056 obs. of  62 variables:
#  $ Country Name  : chr  "Arab World" "Arab World" "Arab World" "Arab World" ...
#  $ Country Code  : chr  "ARB" "ARB" "ARB" "ARB" ...
#  $ Indicator Name: chr  "2005 PPP conversion factor, GDP (LCU per international $)" "2005 PPP conversion factor, private consumption (LCU per international $)" "Access to clean fuels and technologies for cooking  (% of population)" "Access to electricity (% of population)" ...
#  $ Indicator Code: chr  "PA.NUS.PPP.05" "PA.NUS.PRVT.PP.05" "EG.CFT.ACCS.ZS" "EG.ELC.ACCS.ZS" ...
# ...

# %% [markdown]
# __The End__

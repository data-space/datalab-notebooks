# %% [markdown]
# # Dataset `yelp`

# %% [markdown]
# ## Contents
# 1. Setup

# %% [markdown]
# ## 1. Setup

# %%
select *
from yelp.business
limit 3

# %%
select *
from yelp.user
limit 3

# %%
select *
from yelp.tip
limit 3

# %%
select *
from yelp.review
limit 3

# %%
select *
from yelp.checkin
limit 3

# %% [markdown]
# __The End__

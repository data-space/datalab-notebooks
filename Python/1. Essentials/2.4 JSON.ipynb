# %% [markdown]
# # JSON in Python
#
# This notebook demonstrates reading JSON data from files into lists, dictionaries, and dataframes in Python.

# %% [markdown]
# Notice the Python version running on the cluster.

# %%
# %python
import sys
sys.version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>&apos;3.5.2 (default, Nov 23 2017, 16:37:01) \n[GCC 5.4.0 20160609]&apos;
# </div>

# %% [markdown]
# ## Contents
# 1. Setup
# 2. List example
# 1. Dictionary example
# 3. Mixed examples
# 1. Realistic examples

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# Load the `pandas` Python library.

# %%
# %python
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# In this notebook we read data from some of these JSON files.

# %%
# %sh ls /dbfs/mnt/datalab-datasets/file-samples/*.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/dbfs/mnt/datalab-datasets/file-samples/companies.json
# /dbfs/mnt/datalab-datasets/file-samples/dict_of_lists.json
# /dbfs/mnt/datalab-datasets/file-samples/each_line.json
# /dbfs/mnt/datalab-datasets/file-samples/enron.json
# /dbfs/mnt/datalab-datasets/file-samples/list_of_dicts.json
# /dbfs/mnt/datalab-datasets/file-samples/one_dictionary.json
# /dbfs/mnt/datalab-datasets/file-samples/one_list.json
# /dbfs/mnt/datalab-datasets/file-samples/one_list_with_metadata.json
# /dbfs/mnt/datalab-datasets/file-samples/simple_dict.json
# /dbfs/mnt/datalab-datasets/file-samples/simple_list.json
# /dbfs/mnt/datalab-datasets/file-samples/stocks.json
# /dbfs/mnt/datalab-datasets/file-samples/world_bank.json
# /dbfs/mnt/datalab-datasets/file-samples/zips.json
# </div>

# %% [markdown]
# The contents of individual files can be displayed with the `head` shell command.
#
# For example, the following command displays the first three lines of the `one_list.json` file. Notice the parameter `-n 3`.
#
# The `%sh` magic at the beginning of the code cell indicates that the cell contains shell commands.

# %%
# %sh head -n 3 /dbfs/mnt/datalab-datasets/file-samples/one_list.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[{
# 	&quot;id&quot;: &quot;ae4d9000001&quot;,
# 	&quot;product_name&quot;: &quot;sildenafil citrate&quot;,
# </div>

# %% [markdown]
# The contents of files are often read into Python using the `open` function. (An example is three cells below.)
# - The first argument to this function is the full path of the file.
# - The second argument is the mode with which to read the file. An `r` indicates the file will be read.
# - The function returns a file object that can be used to read (in this case) from the indicated file.
# - See the documentation https://docs.python.org/3.5/library/functions.html#open for details.

# %% [markdown]
# The `with` command (in the example two cells below) is called a _context manager_.
#
# In the cell below (and in many cells below that), the `with` command opens the file and stores the _file object_, returned by the `open` function, in the `infile` variable. All indented commands that follow the `with` command can access this variable and the contents of the file, but when the indentation stops then the file object is deleted and it is no longer possible to read from the file.
#
# The basic reason to use the `with` and `open` statements like this is to automatically close the file after the indented commands are run.
# There are more complicated reasons to use them, but they're not that important (to know) if you __always__ use it to open files for reading or writing.

# %% [markdown]
# The following code cell:
# 1. opens the `simple_list.json` file for reading
# 2. loads the contents of the file into a list (using the `load` function from the `json` module)
# 3. stores this list in `list_from_file`
# 4. displays the list (as it is the last command of the cell)

# %%
# %python
with open('/dbfs/mnt/datalab-datasets/file-samples/simple_list.json', 'r') as infile:
  list_from_file = json.load(infile)

list_from_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">50</span><span class="ansired">]: </span>[10, 20, 30]
# </div>

# %% [markdown]
# Notice the resulting list (above) corresponds exactly to the characters from the file (below).

# %%
# %sh head -n 3 /dbfs/mnt/datalab-datasets/file-samples/simple_list.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[10, 20, 30]
# </div>

# %% [markdown]
# The remaining sections of this notebook demonstrate the reading of JSON text (from files) into Python lists. dictionaries, and tables.

# %% [markdown]
# ## 2. List example

# %% [markdown]
# The `json` library provides Python functions to read and write JSON text.
#
# The `loads` function:
# - expects its argument to be a string of JSON data and
# - returns the Python object (usually a list or dictionary) that corresponds to the JSON data

# %%
# %python
import json
my_json = json.loads('["hello","goodbye",777,null]')
my_json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>[&apos;hello&apos;, &apos;goodbye&apos;, 777, None]
# </div>

# %% [markdown]
# The `null` JSON value is often used to indicate missing data. Notice that this value corresponds to the `None` value in Python.

# %% [markdown]
# The JSON text for the next example comes from the file `simple_list.json`, which is displayed below.
#
# This is the same example as above in the Setup section. The following command displays the contents of this file (which only contains one line).

# %%
# %sh head -n 3 /dbfs/mnt/datalab-datasets/file-samples/simple_list.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[10, 20, 30]
# </div>

# %% [markdown]
# The following code reads the contents of the file `simple_list.json` into a Python list.

# %%
# %python
import json
with open("/dbfs/mnt/datalab-datasets/file-samples/simple_list.json", 'r') as infile:
  list_from_file = json.load(infile)
  
list_from_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>[10, 20, 30]
# </div>

# %% [markdown]
# The following code demonstrates that the `load` function does in fact return a list.

# %%
# %python 
type(list_from_file), list_from_file[-1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">52</span><span class="ansired">]: </span>(list, 30)
# </div>

# %% [markdown]
# ## 2. Dictionary example

# %% [markdown]
# The JSON text for this example comes from the file `simple_dict.json`, which is displayed below.

# %%
# %sh cat /dbfs/mnt/datalab-datasets/file-samples/simple_dict.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;a&quot;:1, &quot;b&quot;:2, &quot;c&quot;:3}
# </div>

# %% [markdown]
# The following code reads the contents of the file `simple_dict.json` into a Python dictionary.

# %%
# %python
with open("/dbfs/mnt/datalab-datasets/file-samples/simple_dict.json", 'r') as infile:
  dict_from_file = json.load(infile)

dict_from_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>{&apos;c&apos;: 3, &apos;a&apos;: 1, &apos;b&apos;: 2}
# </div>

# %%
# %python
dict_from_file.get('b')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>2
# </div>

# %% [markdown]
# ## 3. Mixed examples

# %% [markdown]
# This section contains two examples, each in a section:
# 1. Dictionary of lists
# 1. List of dictionaries

# %% [markdown]
# ### 3.1 Dictionary of lists

# %%
# %sh cat /dbfs/mnt/datalab-datasets/file-samples/dict_of_lists.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;a&quot;:[1,2,3], &quot;b&quot;:[4,5,6], &quot;c&quot;:[7,8,9]}
# </div>

# %% [markdown]
# The following code reads the contents of the file `dict_of_lists.json` into a Python dictionary.

# %%
# %python
with open("/dbfs/mnt/datalab-datasets/file-samples/dict_of_lists.json", 'r') as infile:
  dict_from_file = json.load(infile)

dict_from_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">56</span><span class="ansired">]: </span>{&apos;c&apos;: [7, 8, 9], &apos;a&apos;: [1, 2, 3], &apos;b&apos;: [4, 5, 6]}
# </div>

# %%
# %python 
type(dict_from_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">57</span><span class="ansired">]: </span>dict
# </div>

# %%
# %python 
dict_from_file.get('b')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">38</span><span class="ansired">]: </span>[4, 5, 6]
# </div>

# %%
# %python 
dict_from_file.get('b')[2]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">41</span><span class="ansired">]: </span>6
# </div>

# %% [markdown]
# ### 3.2 List of dictionaries

# %%
# %sh cat /dbfs/mnt/datalab-datasets/file-samples/list_of_dicts.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[{&quot;a&quot;:1, &quot;b&quot;:2, &quot;c&quot;:3}, {&quot;d&quot;:4, &quot;e&quot;:5, &quot;f&quot;:6}]
# </div>

# %% [markdown]
# The following code reads the contents of the file `list_of_dicts.json` into a Python list with items that are dictionaries.

# %%
# %python
with open("/dbfs/mnt/datalab-datasets/file-samples/list_of_dicts.json", 'r') as infile:
  dict_from_file = json.load(infile)

dict_from_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">59</span><span class="ansired">]: </span>[{&apos;c&apos;: 3, &apos;a&apos;: 1, &apos;b&apos;: 2}, {&apos;e&apos;: 5, &apos;f&apos;: 6, &apos;d&apos;: 4}]
# </div>

# %%
# %python
type(dict_from_file), dict_from_file[1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">60</span><span class="ansired">]: </span>(list, {&apos;e&apos;: 5, &apos;f&apos;: 6, &apos;d&apos;: 4})
# </div>

# %%
# %python
dict_from_file[1].get('d')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">44</span><span class="ansired">]: </span>4
# </div>

# %% [markdown]
# ## 4. More realistic examples

# %% [markdown]
# The three subsections below demonstrate three ways in which tables are stored in JSON formatted files.
# These three ways are distinguished by the format of JSON data stored in the file to be read.
# The JSON data is:
# 1. A list of dictionaries
# 1. A dictionary contains a list of dictionaries
# 1. Each line of the file is a dictionary
#
# In each of the three cases above, the dictionaries correspond to records of the table stored in the file.

# %% [markdown]
# ### 4.1 Dataset from a single list of JSON records

# %%
# %sh head -n 30 /dbfs/mnt/datalab-datasets/file-samples/one_list.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[{
# 	&quot;id&quot;: &quot;ae4d9000001&quot;,
# 	&quot;product_name&quot;: &quot;sildenafil citrate&quot;,
# 	&quot;supplier&quot;: &quot;Wisozk Inc&quot;,
# 	&quot;quantity&quot;: 261,
# 	&quot;unit_cost&quot;: &quot;$10.47&quot;
# },
# {
# 	&quot;id&quot;: &quot;ae4d9000002&quot;,
# 	&quot;product_name&quot;: &quot;Mountain Juniperus ashei&quot;,
# 	&quot;supplier&quot;: &quot;Keebler-Hilpert&quot;,
# 	&quot;quantity&quot;: 292,
# 	&quot;unit_cost&quot;: &quot;$8.74&quot;
# },
# {
# 	&quot;id&quot;: &quot;ae4d9000003&quot;,
# 	&quot;product_name&quot;: &quot;Dextromathorphan HBr&quot;,
# 	&quot;supplier&quot;: &quot;Schmitt-Weissnat&quot;,
# 	&quot;quantity&quot;: 211,
# 	&quot;unit_cost&quot;: &quot;$20.53&quot;
# }]
# </div>

# %% [markdown]
# The following code reads the contents of the file `one_list.json` into a Python list of dictionaries

# %%
# %python
import json
with open('/dbfs/mnt/datalab-datasets/file-samples/one_list.json', 'r') as infile:
  dict_from_file = json.load(infile)
  
dict_from_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>
# [{&apos;product_name&apos;: &apos;sildenafil citrate&apos;,
#   &apos;quantity&apos;: 261,
#   &apos;supplier&apos;: &apos;Wisozk Inc&apos;,
#   &apos;id&apos;: &apos;ae4d9000001&apos;,
#   &apos;unit_cost&apos;: &apos;$10.47&apos;},
#  {&apos;product_name&apos;: &apos;Mountain Juniperus ashei&apos;,
#   &apos;quantity&apos;: 292,
#   &apos;supplier&apos;: &apos;Keebler-Hilpert&apos;,
#   &apos;id&apos;: &apos;ae4d9000002&apos;,
#   &apos;unit_cost&apos;: &apos;$8.74&apos;},
#  {&apos;product_name&apos;: &apos;Dextromathorphan HBr&apos;,
#   &apos;quantity&apos;: 211,
#   &apos;supplier&apos;: &apos;Schmitt-Weissnat&apos;,
#   &apos;id&apos;: &apos;ae4d9000003&apos;,
#   &apos;unit_cost&apos;: &apos;$20.53&apos;}]
# </div>

# %% [markdown]
# The pandas `DataFrame` constructor can take as input a list of dictionaries.
#
# The keys of the dictionaries are interpreted as column names.

# %%
# %python 
import pandas as pd 
pd.DataFrame(data=dict_from_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>
#             id              product_name  quantity          supplier unit_cost
# 0  ae4d9000001        sildenafil citrate       261        Wisozk Inc    $10.47
# 1  ae4d9000002  Mountain Juniperus ashei       292   Keebler-Hilpert     $8.74
# 2  ae4d9000003      Dextromathorphan HBr       211  Schmitt-Weissnat    $20.53
# </div>

# %% [markdown]
# ### 4.2 Dataset from single dictionary

# %%
# %sh head -n 9 /dbfs/mnt/datalab-datasets/file-samples/one_dictionary.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;metadata&quot;: {&quot;author&quot;: &quot;David Oury&quot;, &quot;date&quot;: &quot;18 Sep 2017&quot;},
#  &quot;data&quot;:
# 	[{
# 		&quot;id&quot;: &quot;ae4d9000001&quot;,
# 		&quot;product_name&quot;: &quot;sildenafil citrate&quot;,
# 		&quot;supplier&quot;: &quot;Wisozk Inc&quot;,
# 		&quot;quantity&quot;: 261,
# 		&quot;unit_cost&quot;: &quot;$10.47&quot;
# 	},
# </div>

# %% [markdown]
# The following code reads the contents of the file `one_dictionary.json` into a Python dictionary.
#
# Notice that the last command converts the dictionary `my_dict_from_file['data']` into a Pandas dataframe.

# %%
# %python
with open('/dbfs/mnt/datalab-datasets/file-samples/one_dictionary.json', 'r') as infile:
  my_dict_from_file = json.load(infile)
my_dict_from_file

pd.DataFrame(data=my_dict_from_file['data'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>
#             id              product_name  quantity          supplier unit_cost
# 0  ae4d9000001        sildenafil citrate       261        Wisozk Inc    $10.47
# 1  ae4d9000002  Mountain Juniperus ashei       292   Keebler-Hilpert     $8.74
# 2  ae4d9000003      Dextromathorphan HBr       211  Schmitt-Weissnat    $20.53
# </div>

# %% [markdown]
# ### 4.3 Dataset from one JSON record per line (JSONL format)

# %% [markdown]
# This is a very brief introduction to the _line delimited_ JSON format. For details see
# - http://ndjson.org/
# - http://jsonlines.org/
# - [Wikipedia](https://en.wikipedia.org/wiki/JSON_streaming)
#
# The acronyms JSONL, NDJSON and LDJSON are equivalent terms and refer to a format where each line of a file contains a single JSON record which is a dictionary and describes a record of data.

# %%
# %sh head -n 7 /dbfs/mnt/datalab-datasets/file-samples/each_line.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{ &quot;id&quot;: &quot;ae4d9000001&quot;, &quot;product_name&quot;: &quot;sildenafil citrate&quot;, &quot;supplier&quot;: &quot;Wisozk Inc&quot;, &quot;quantity&quot;: 261, &quot;unit_cost&quot;: &quot;$10.47&quot; }
# { &quot;id&quot;: &quot;ae4d9000002&quot;, &quot;product_name&quot;: &quot;Mountain Juniperus ashei&quot;, &quot;supplier&quot;: &quot;Keebler-Hilpert&quot;, &quot;quantity&quot;: 292, &quot;unit_cost&quot;: &quot;$8.74&quot; }
# { &quot;id&quot;: &quot;ae4d9000003&quot;, &quot;product_name&quot;: &quot;Dextromathorphan HBr&quot;, &quot;supplier&quot;: &quot;Schmitt-Weissnat&quot;, &quot;quantity&quot;: 211, &quot;unit_cost&quot;: &quot;$20.53&quot; }
# </div>

# %% [markdown]
# This next example introduces the `jsonlines` package (from Python).
#
# The `open` function (in this package) reads a file in JSONL and returns a list of dictionaries.

# %%
# %python
import pandas as pd
import jsonlines
list_of_dictionaries = list(jsonlines.open("/dbfs/mnt/datalab-datasets/file-samples/each_line.json"))
list_of_dictionaries
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>
# [{&apos;supplier&apos;: &apos;Wisozk Inc&apos;,
#   &apos;quantity&apos;: 261,
#   &apos;unit_cost&apos;: &apos;$10.47&apos;,
#   &apos;id&apos;: &apos;ae4d9000001&apos;,
#   &apos;product_name&apos;: &apos;sildenafil citrate&apos;},
#  {&apos;supplier&apos;: &apos;Keebler-Hilpert&apos;,
#   &apos;quantity&apos;: 292,
#   &apos;unit_cost&apos;: &apos;$8.74&apos;,
#   &apos;id&apos;: &apos;ae4d9000002&apos;,
#   &apos;product_name&apos;: &apos;Mountain Juniperus ashei&apos;},
#  {&apos;supplier&apos;: &apos;Schmitt-Weissnat&apos;,
#   &apos;quantity&apos;: 211,
#   &apos;unit_cost&apos;: &apos;$20.53&apos;,
#   &apos;id&apos;: &apos;ae4d9000003&apos;,
#   &apos;product_name&apos;: &apos;Dextromathorphan HBr&apos;}]
# </div>

# %%
# %python
pdf_from_list_of_dictionaries = pd.DataFrame(data=list_of_dictionaries)
pdf_from_list_of_dictionaries
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>
#             id              product_name  quantity          supplier unit_cost
# 0  ae4d9000001        sildenafil citrate       261        Wisozk Inc    $10.47
# 1  ae4d9000002  Mountain Juniperus ashei       292   Keebler-Hilpert     $8.74
# 2  ae4d9000003      Dextromathorphan HBr       211  Schmitt-Weissnat    $20.53
# </div>

# %%
# %python
pdf_from_list_of_dictionaries.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
# id              3 non-null object
# product_name    3 non-null object
# quantity        3 non-null int64
# supplier        3 non-null object
# unit_cost       3 non-null object
# dtypes: int64(1), object(4)
# memory usage: 200.0+ bytes
# </div>

# %% [markdown]
# __The End__

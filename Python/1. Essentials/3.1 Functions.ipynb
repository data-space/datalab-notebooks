# %% [markdown]
# # Functions

# %% [markdown]
# ## Table of Contents
#
# 1. Creating functions
# 1. Default parameters
# 1. Help on functions

# %% [markdown]
# ## 1. Creating Functions

# %% [markdown]
# Functions have
# - Input parameters
# - Output results
# - One or more commands that are run when the function is called
#
# Functions can be created in two ways (in Python.)
# 1. Using the `def` keyword
# 1. Using the `lambda` keyword

# %% [markdown]
# ### 1.1 Keyword `def`

# %% [markdown]
# First create a function that contains a single command.

# %%
def plus_1(x):
  return(x+1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
plus_1(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>3
# </div>

# %% [markdown]
# Now create a function with a sequence of commands.
#
# The commands listed after the first line must be identically indented, otherwise you will get an error.

# %%
def multi_line_function(input1, input2): 
  input1.reverse()
  input2 = 2
  return(input1 * input2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
multi_line_function(['a','b'],3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>[&apos;b&apos;, &apos;a&apos;, &apos;b&apos;, &apos;a&apos;]
# </div>

# %% [markdown]
# __Exercise__: Explain why the function only returns a list with two (reversed) copies of the first parameter (not three.)

# %% [markdown]
# Function parameters are new names for the input values.
#
# Study the next three code blocks and their output.

# %%
test1 = ['a', 'b']
test2 = 9
multi_line_function(test1, test2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>[&apos;b&apos;, &apos;a&apos;, &apos;b&apos;, &apos;a&apos;]
# </div>

# %% [markdown]
# Notice that the contents of the `test1` variable was changed by the function.

# %%
test1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>[&apos;b&apos;, &apos;a&apos;]
# </div>

# %% [markdown]
# Notice that the contents of the `test2` variable was __not__ changed by the function.

# %%
test2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>9
# </div>

# %% [markdown]
# Explain Spock.
# 1. Function parameters are new names for the input values. For each parameter we have one value with two names.
# 1. An assignment statement first creates a new object from the expression to the right of the `=`. Then it points the name (found to the left of the `=`) to the newly created object. This process won't change the object stored in a variable outside the function.
# 1. When the object pointed to by a parameter is modified or changed, the input variable and parameter variable both point to that same __changed__ object.

# %% [markdown]
# ### 1.2 Keyword `lambda`

# %% [markdown]
# The `lambda` function creates functions which consist of a single command. The entire `lambda` command is written on one line.
#
# These functions can be stored in a variable (see next cell) or passed to another function (see further below.)

# %%
times_2 = lambda x: 2*x
times_3 = lambda x: 3*x
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
times_2(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>6
# </div>

# %% [markdown]
# The `myapply` function (below) takes two parameters:
# - The first parameter should be a function.
# - The second parameter is used as input to the function (which is the first parameter.)

# %%
my_apply = lambda myFunc, myNumber: myFunc(myNumber)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_apply(times_2, 10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>20
# </div>

# %%
times_2(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>20
# </div>

# %%
my_apply(times_3, 1000)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>3000
# </div>

# %%
my_apply(lambda x: 4*x, 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>4
# </div>

# %% [markdown]
# __Exercise__:
# - Create a function `add` which has two inputs and returns their sum. Use the function to demonstrate that it works.
# - Create a function `times` which has two inputs and returns their product. Use the function to demonstrate that it works.
# - Create a function `apply` which has three inputs and returns the result of the first parameter,
# which is a function with two parameters, with inputs from the second and third parameters.
# Use the function to demonstrate that it works.
#
# For example, demonstrate that `apply(add,2,3)` returns `5` and `apply(times,2,3)` returns `6`.

# %% [markdown]
# ### Default Parameters
#
# Many Python functions, for instance `sorted`, have optional/default parameters.

# %%
sorted([4,3,9])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>[3, 4, 9]
# </div>

# %%
sorted([4,3,9], reverse=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>[3, 4, 9]
# </div>

# %%
sorted([4,3,9], reverse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>[9, 4, 3]
# </div>

# %% [markdown]
# __Exercises:__ Create a function named `optfun` with a single parameter with default value `2` that returns `10` times the value of the first parameter.
#
# Demonstrate that `optfun()` returns `20` and `optfun(3)` returns `30`.

# %% [markdown]
# ## 3. Help on Functions

# %% [markdown]
# Documentation for most functions that come with Python or with imported libraries is available from the `help` function.

# %%
help(len)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
#
# </div>

# %%
help(sorted)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Help on built-in function sorted in module builtins:
#
# sorted(iterable, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customise the sort order, and the
#     reverse flag can be set to request the result in descending order.
#
# </div>

# %% [markdown]
# __The End__

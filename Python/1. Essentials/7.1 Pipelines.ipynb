# %% [markdown]
# # Pipelines

# %% [markdown]
# ## Table of Contents
# 1. Setup
# 1. Pipelines

# %% [markdown]
# ## Setup

# %% [markdown]
# Import `pandas`, `numpy` and `sklearn`. Note the corresponding versions.

# %%
import pandas  as pd
import numpy   as np
import sklearn as sk
pd.__version__, np.__version__, sk.__version__
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>(&apos;0.19.2&apos;, &apos;1.11.1&apos;, &apos;0.18.1&apos;)
# </div>

# %% [markdown]
# Related Scikit-learn documentation, for the version we are using, can be found at:
# - Documentation: http://scikit-learn.org/0.18/documentation.html
# - User guide: http://scikit-learn.org/0.18/user_guide.html
# - Pipelines: http://scikit-learn.org/0.18/modules/pipeline.html
# - Data transformations: http://scikit-learn.org/0.18/data_transforms.html
#     - Prepreprocess: http://scikit-learn.org/0.18/modules/preprocessing.html#preprocessing
#     - Feature extraction: http://scikit-learn.org/0.18/modules/feature_extraction.html#feature-extraction
#     - Unsupervised dimensionality reduction: http://scikit-learn.org/0.18/modules/unsupervised_reduction.html#data-reduction
#     - Expand (kernel approximation): http://scikit-learn.org/0.18/modules/kernel_approximation.html#kernel-approximation

# %% [markdown]
# ### Setup Dataset

# %% [markdown]
# The first two columns will be treated as numeric. The last column will be treated as categorical.

# %%
data_array = np.array([[1,  np.NaN, 1],
                       [6,  0,      2],
                       [11, 10,     3],
                       [8,  8,      np.NaN]
                      ])
data_array
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>
# array([[ 1., nan,  1.],
#        [ 6.,  0.,  2.],
#        [11., 10.,  3.],
#        [ 8.,  8., nan]])
# </div>

# %%
from sklearn import pipeline
from sklearn import preprocessing

num_pipeline = pipeline.Pipeline([
        ('imputer',       preprocessing.Imputer(strategy="mean")),
    ])
num_pipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>Pipeline(steps=[(&apos;imputer&apos;, Imputer(axis=0, copy=True, missing_values=&apos;NaN&apos;, strategy=&apos;mean&apos;, verbose=0))])
# </div>

# %% [markdown]
# ## Pipelines

# %%
data_array[:,[1]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>
# array([[nan],
#        [ 0.],
#        [10.],
#        [ 8.]])
# </div>

# %%
num_pipeline.fit_transform(data_array[:,[1]])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>
# array([[ 6.],
#        [ 0.],
#        [10.],
#        [ 8.]])
# </div>

# %%
from sklearn.preprocessing import Imputer
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
imp.fit([[1, 2], 
         [np.nan, 3], 
         [7, 6]])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>Imputer(axis=0, copy=True, missing_values=&apos;NaN&apos;, strategy=&apos;mean&apos;, verbose=0)
# </div>

# %%
imp.statistics_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>array([4.        , 3.66666667])
# </div>

# %%
X = [[np.nan, 2], 
     [6, np.nan], 
     [9, 0]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(imp.transform(X))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[[4.         2.        ]
#  [6.         3.66666667]
#  [9.         0.        ]]
# </div>

# %% [markdown]
# A `Pipeline` object takes as input a list of tuples where each tuple has:
# - A name (`string`)
# - A transformer object
#
# Below two transformers are run in sequence. The `fit` method of the second takes as input the output from the `transform` method of the first.

# %%
from sklearn import pipeline
from sklearn import preprocessing

num_pipeline = pipeline.Pipeline([('imputer', preprocessing.Imputer(strategy="median")),
                                  ('scaler',  preprocessing.MinMaxScaler())
    ])
num_pipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">21</span><span class="ansired">]: </span>Pipeline(steps=[(&apos;imputer&apos;, Imputer(axis=0, copy=True, missing_values=&apos;NaN&apos;, strategy=&apos;median&apos;, verbose=0)), (&apos;scaler&apos;, MinMaxScaler(copy=True, feature_range=(0, 1)))])
# </div>

# %%
data_array[:,[0,1]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>
# array([[ 1., nan],
#        [ 6.,  0.],
#        [11., 10.],
#        [ 8.,  8.]])
# </div>

# %%
num_pipeline.fit_transform(data_array[:,[0,1]])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">23</span><span class="ansired">]: </span>
# array([[0. , 0.8],
#        [0.5, 0. ],
#        [1. , 1. ],
#        [0.7, 0.8]])
# </div>

# %% [markdown]
# This completes the numeric pipeline (`num_pipeline`) for this demonstration. Now we create a categorical pipeline (`cat_pipeline`.)

# %%
data_array[:,[2]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>
# array([[ 1.],
#        [ 2.],
#        [ 3.],
#        [nan]])
# </div>

# %%
0,
0.5,
1,
0.5

# %%
from sklearn import pipeline
from sklearn import preprocessing

cat_pipeline = pipeline.Pipeline([('imputer', preprocessing.Imputer(strategy="median")),
                                  ('scaler',  preprocessing.MinMaxScaler()),
                                  ('onehot',  preprocessing.OneHotEncoder())
                                 ])
cat_pipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">31</span><span class="ansired">]: </span>
# Pipeline(steps=[(&apos;imputer&apos;, Imputer(axis=0, copy=True, missing_values=&apos;NaN&apos;, strategy=&apos;median&apos;, verbose=0)), (&apos;scaler&apos;, MinMaxScaler(copy=True, feature_range=(0, 1))), (&apos;onehot&apos;, OneHotEncoder(categorical_features=&apos;all&apos;, dtype=&lt;class &apos;numpy.float64&apos;&gt;,
#        handle_unknown=&apos;error&apos;, n_values=&apos;auto&apos;, sparse=True))])
# </div>

# %%
cat_pipeline.fit_transform(data_array[:,[2]]).toarray()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>
# array([[1., 0.],
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]])
# </div>

# %% [markdown]
# __The End__

# %% [markdown]
# # Comprehensions

# %% [markdown]
# - http://book.pythontips.com/en/latest/comprehensions.html

# %% [markdown]
# ## 1. List Comprehensions

# %% [markdown]
# List comprehensions might be thought of as an oddly formatted `for` loop inside square brackets that results in a list.
#
# First we demonstrate a `for` loop:

# %%
list(range(5))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>[0, 1, 2, 3, 4]
# </div>

# %%
for number in list(range(5)):
  print(number*"abc")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# abc
# abcabc
# abcabcabc
# abcabcabcabc
# </div>

# %% [markdown]
# Notice that the loop does not have a return value (it only prints) and the values returned by `list(range(5))` (below).

# %% [markdown]
# A list comprehension (see below) does the same work as the command below, but:
# - has a return value
# - cannot print

# %%
multiples = [item*10 for item in range(5)]
multiples
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>[0, 10, 20, 30, 40]
# </div>

# %% [markdown]
# An `if` clause can be added to return only values that match a specified condition.

# %%
multiples = [x*10 for x in range(5) if x % 2 == 0]
multiples
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>[0, 20, 40]
# </div>

# %% [markdown]
# This operation (returning a list to be stored in a variable) could be accomplished with a `for` loop, but it looks a bit awkward.

# %%
y = []
for x in range(5):
  if x % 2 == 0:
    y.append(x*10)
y
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>[0, 20, 40]
# </div>

# %% [markdown]
# It is better programming practice to use list comprehensions instead of the `append` method.

# %% [markdown]
# List comprehensions can be nested.

# %%
[10*x*y for x in [1,2,3] for y in [1, -1]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>[10, -10, 20, -20, 30, -30]
# </div>

# %% [markdown]
# Notice that the resulting list contains one element for every combination of `x` in `[1,2,3]` and `y` in `[1, -1]`.

# %% [markdown]
# Dictionary and set comprehensions can also be nested, but this is not demonstrated below.

# %% [markdown]
# ## 2. Dictionary Comprehensions

# %% [markdown]
# Dictionary comprehensions might be thought of as an oddly formatted `for` loop inside curly brackets that results in a dictionary.
#
# First create a sample dictionary.

# %%
some_dict = {"a":1, "b":2, "c":3, "d":4}
some_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>{&apos;a&apos;: 1, &apos;b&apos;: 2, &apos;c&apos;: 3, &apos;d&apos;: 4}
# </div>

# %% [markdown]
# Recall that the elements of a dictionary are key-value pairs.
# These pairs can be retrieved with the `items` method.

# %%
some_dict.items()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>dict_items([(&apos;a&apos;, 1), (&apos;b&apos;, 2), (&apos;c&apos;, 3), (&apos;d&apos;, 4)])
# </div>

# %% [markdown]
# Notice that the `items()` method returns a list of 2-tuples.

# %% [markdown]
# The `list` function can return this into a familiar list.

# %%
list(some_dict.items())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>[(&apos;a&apos;, 1), (&apos;b&apos;, 2), (&apos;c&apos;, 3), (&apos;d&apos;, 4)]
# </div>

# %% [markdown]
# A dictionary can be created from the 2-tuples returns by the `items` method.
#
# The dictionary comprehension created below contains only the key-value pairs where the value is even.

# %%
{k:v
   for (k, v)
   in some_dict.items()
   if v % 2 == 0
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>{&apos;d&apos;: 4, &apos;b&apos;: 2}
# </div>

# %% [markdown]
# Notice that the key and value of the resulting dictionary can be changed.

# %%
{k:10*v
 for (k, v)
 in some_dict.items()
 if v % 2 == 0
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>{&apos;b&apos;: 20, &apos;d&apos;: 40}
# </div>

# %% [markdown]
# Notice,  that the value was changed above and the key is changed below.

# %%
{k+k:v
   for (k, v)
   in some_dict.items()
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>{&apos;bb&apos;: 2, &apos;dd&apos;: 4, &apos;cc&apos;: 3, &apos;aa&apos;: 1}
# </div>

# %% [markdown]
# Of course, both can be changed.

# %%
{k+k:10*v
   for k, v
   in some_dict.items()
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>{&apos;bb&apos;: 20, &apos;dd&apos;: 40, &apos;cc&apos;: 30, &apos;aa&apos;: 10}
# </div>

# %% [markdown]
# ## 3. Set Comprehensions

# %% [markdown]
# A set comprehension looks like a dictionary comprehension, but does not include a value.
#
# For this reason it will not contain duplicates.

# %%
squared = {x**2  for x in [-1, 1, 2]}
squared
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>{1, 4}
# </div>

# %%
{(m, n) for n in range(2) for m in range(3, 5)}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>{(3, 0), (3, 1), (4, 0), (4, 1)}
# </div>

# %% [markdown]
# Notice that set comprehensions do not have duplicates.

# %% [markdown]
# __The End__

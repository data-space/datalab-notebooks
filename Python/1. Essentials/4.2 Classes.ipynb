# %% [markdown]
# # Python Classes

# %% [markdown]
# ## Table of Contents
# 1. Defining classes
# 1. Creating object from class
# 1. Example : the `Temperature` class
# 1. Exercise

# %% [markdown]
# Check that we are running Python 3.

# %%
import sys
sys.version

# %% [markdown]
# ## Defining classes

# %% [markdown]
# Classes are templates for creating objects. These objects (also called instances) have _attributes_ and _methods_:
# - Attributes are variables that are defined in the class
# - Methods are functions that are defined in the class
#
# Every class/object has a special method named `__init__` which is called when the object is created.
#
# It is used to set the _initial_ values of the object's attributes.

# %%
class Dog:
  
  def __init__(self, name):
    self.name = name    # instance variable unique to each instance

# %% [markdown]
# ##Creating objects

# %% [markdown]
# The `name` parameter is set to `'Fido'` when the `Dog` object is created below.
# This object is stored in variable `f`.
#
# Notice the value of the `name` attribute.

# %%
f = Dog('Fido')
f, f.name
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>(&lt;__main__.Dog at 0x7fda9c611908&gt;, &apos;Fido&apos;)
# </div>

# %% [markdown]
# Another `Dog` object is created and stored in `m`.

# %%
m = Dog('Daisy')
m, m.name
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>(&lt;__main__.Dog at 0x7fda9c6117f0&gt;, &apos;Daisy&apos;)
# </div>

# %% [markdown]
# ##Example: the `Temperature` class

# %% [markdown]
# The `Temperature` class has an `__init__` method that has two parameters.
# The second has a default value and so is optional.
#
# The `set_temp` method sets the `temp` attribute of the object and returns the object itself.
#
# The `get_temp` and `get_units` methods return values.

# %%
class Temperature:

    def __init__(self, temp, units='Celsius'):
        self.temp  = temp
        self.units = units
        
    def set_temp(self,temp):
        self.temp = temp
        return self
      
    def get_temp(self):
        return self.temp
      
    def get_units(self):
        return self.units
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
t = Temperature(36.0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
t.get_temp(), t.get_units()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>(36.0, &apos;Celsius&apos;)
# </div>

# %% [markdown]
# Create another instance `t2` of the `Temperature` class.

# %%
t2 = Temperature(60)
t2.get_temp(), t2.get_units()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>(60, &apos;Celsius&apos;)
# </div>

# %% [markdown]
# Notice that the temperature is different in the different objects (`t` and `t2`).

# %% [markdown]
# Access the `units` attribute of the object `a` using dot notation.

# %%
t2.units
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>&apos;Celsius&apos;
# </div>

# %% [markdown]
# The `set_temp` method sets the `temp` attribute of the object and returns the object itself.

# %%
t2.set_temp(40), t2.get_temp()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>(&lt;__main__.Temperature at 0x7f7538495ba8&gt;, 40)
# </div>

# %% [markdown]
# __Exercise:__ Modify the `MultipleItems` class below to add:
# - a method `get_cost` which returns the value of the `cost` attribute
# - a method `set_number` with one parameter `number` which changes the `number` attribute and returns `self`
# - a method `get_total_cost` which returns the product of the `cost` and `number` attributes

# %%
class MultipleItems:
  
  def __init__(self, name='default', cost=1.00, number=1):
    self.name   = name    # name of item
    self.number = number  # number of items
    self.cost   = cost    # cost per item
  
  def set_cost(self, cost):
    self.cost = cost
    return self
  def get_number(self):
    return self.number
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# __Exercise:__ Check your modifications to the above class by running these commands (in this order):
# 1. `x = MultipleItems(name='sandwich')`
# 1. `x.set_number(10)`
# 1. `x.set_cost(9.95)`
# 1. `x.name, x.get_cost(), x.get_number(), x.get_total_cost()`

# %% [markdown]
# __Exercise:__ Define a class called `Lunch`:
#
# Its `__init__()` method should have two arguments: `self` and `menu`. The init method sets the attribute `menu` which is a string.
#
# Add a method called `menu_price`. It will involve an `if-elif-else` statement:
#
# - if the attribute `menu` is "menu 1", print `Your choice: menu 1 Price 12.00`.
# - if the attribute `menu` is "menu 2", print `Your choice: menu 2 Price 13.40`.
# - else print `"Error in menu"`.
#
# To check if it works: define `Paul=Lunch("menu 1")` and call `Paul.menu_price()`.

# %%
class Lunch:
  
  def __init__(self, menu):
    self.menu = menu
  
  def menu_price(self):
    if self.menu == 'menu 1':
      print('Your choice: menu 1 Price 12.00')
    elif self.menu == 'menu 2':
      print('Your choice: menu 2 Price 13.40')
    else:
      print('Error in menu')
    return self
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Paul = Lunch('menu 1')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Paul.menu_price()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Your choice: menu 1 Price 12.00
# <span class="ansired">Out[</span><span class="ansired">33</span><span class="ansired">]: </span>&lt;__main__.Lunch at 0x7fda9c611978&gt;
# </div>

# %%
class Lunch(object):
    def __init__(self,menu):
      self.menu=str(menu)
      
    def menu_price(self):
       if self.menu=="menu 1":
          print ("Your choice:", self.menu, "Price 12.00")
      
       elif self.menu=="menu 2":
          print ("Your choice:", self.menu, "Price 13.40")
    
       else:
          print ("Error in menu")

Paul=Lunch("menu 1")
Paul.menu_price()

# %% [markdown]
# Tutorials on classes:
# - https://www.learnpython.org/en/Classes_and_Objects
# - http://thepythonguru.com/python-object-and-classes/
# - https://docs.python.org/3/tutorial/classes.html

# %% [markdown]
# __The End__

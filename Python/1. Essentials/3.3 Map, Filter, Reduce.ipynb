# %% [markdown]
# # Map, Filter, Reduce

# %% [markdown]
# ## Contents
# 1. Map
# 2. Filter
# 3. Reduce

# %% [markdown]
# See also:
# - http://book.pythontips.com/en/latest/map_filter.html
# - https://www.python-course.eu/lambda.php

# %% [markdown]
# The `map` and `filter` functions provide an alternative to list comprehensions.
#
# Sometimes they are more readable than comprehensions, but sometimes they are less readable.

# %% [markdown]
# ## 1. Map

# %% [markdown]
# Recall that `lambda` creates an anonymous function, which can be stored in a variable.

# %%
add = lambda x, y: x + y
add(4, 5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>9
# </div>

# %% [markdown]
# Create a function that multiplies its argument by `10`.

# %%
times_ten = lambda x: x*10 
times_ten
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>&lt;function __main__.&lt;lambda&gt;&gt;
# </div>

# %% [markdown]
# Call this function with `2` as input.

# %%
times_ten(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>20
# </div>

# %% [markdown]
# Now create a list (of inputs) that we will supply to the function.

# %%
list_of_inputs = [1,2,3]
list_of_inputs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>[1, 2, 3]
# </div>

# %%
list(map(times_ten, list_of_inputs))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>[10, 20, 30]
# </div>

# %% [markdown]
# Notice that the `map` function runs `times_ten` on each element of `list_of_inputs` and then returns these results as a list.
#
# The `list` function must be called on the output of `map` as it (`map`) returns a _generator_ which we won't describe in this notebook.

# %% [markdown]
# Documentation on `map` and `filter` can be found at:
# - http://book.pythontips.com/en/latest/map_filter.html

# %% [markdown]
# The input parameters to `map` can be supplied directly.

# %%
list(map(lambda x: x**2,
         [1, 2, 3, 4, 5]
        ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>[1, 4, 9, 16, 25]
# </div>

# %% [markdown]
# ### 1.1 For loops
#
# The `for` command iterates through a sequence of items (called an _iterable_) and assigns each in turn to a variable. Then the statements are run.
#
# The `for` command below squares and _prints_ each number in `items`.

# %%
items = [1, 2, 3, 4, 5]
for i in items:
   print(i**2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 4
# 9
# 16
# 25
# </div>

# %% [markdown]
# The following `for` command returns the list of squares of each item in the `items` list.

# %%
items = [1, 2, 3, 4, 5]
squared = []
for i in items:
    squared.append(i**2)
squared
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>[1, 4, 9, 16, 25]
# </div>

# %% [markdown]
# The `map` command returns the list of squares of each item in the `items` list (same as above).

# %%
items = [1, 2, 3, 4, 5]
list(map(lambda x: x**2,
         items
        ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>[1, 4, 9, 16, 25]
# </div>

# %% [markdown]
# ## 2. Filter

# %% [markdown]
# The `filter` function returns only those elements from its second argument (a list) for which the first argument returns `True`.

# %%
list(filter(lambda x: x < 0, 
            range(-3,3)
           ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>[-3, -2, -1]
# </div>

# %% [markdown]
# The list comprehension below produces the same output as the command above that uses the `filter` function.

# %%
[item for item in range(-3,3) if item < 0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>[-3, -2, -1]
# </div>

# %% [markdown]
# ## 3. Reduce

# %% [markdown]
# The `reduce` function from the `functools` library applies a function (the first argument) to pairs of elements from a list (the second argument) and then to pairs of the results of the function to _reduce_ the function to a single value.
#
# Documentation on the `reduce` function can be found at:
# - http://book.pythontips.com/en/latest/map_filter.html

# %% [markdown]
# The `reduce` command below produces the same result as the following code cell with the `for` loop.

# %%
from functools import reduce
reduce(lambda x, y: x * y, 
       [1, 2, 3, 4])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>24
# </div>

# %%
product = 1
my_list = [1, 2, 3, 4]

for num in my_list:
    product = product * num

product
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>24
# </div>

# %% [markdown]
# __The End__

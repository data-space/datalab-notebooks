# %% [markdown]
# # Python Dictionaries

# %% [markdown]
# ## Table of Contents
#
# 1. Creating Dictionaries
# 1. Accessing Dictionaries
# 1. Manipulating Dictionaries
# 1. Operations on Dictionaries

# %% [markdown]
# ## Creating Dictionaries

# %% [markdown]
# Dictionaries are collections of _key_-_value_ pairs separated by commas and enclosed in braces.
#
# Below the keys are the country names and the values are the city names.

# %%
europe_cities = {'spain'  :['madrid', 'barcelona', 'seville', 'valencia'], 
                 'france' :['paris', 'marseille', 'bordeaux'], 
                 'germany':['berlin', 'munich'], 
                 'norway' :['oslo'] }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
europe_cap_pop = {'spain'  : { 'capital':'madrid' , 'population':46.77 },
                  'france' : { 'capital':'paris'  , 'population':66.03 },
                  'germany': { 'capital':'berlin' , 'population':80.62 },
                  'norway' : { 'capital':'oslo'   , 'population': 5.84 } }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Accessing Dictionaries

# %%
europe_cities['germany']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">46</span><span class="ansired">]: </span>[&apos;berlin&apos;, &apos;munich&apos;]
# </div>

# %%
europe_cap_pop['germany']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">47</span><span class="ansired">]: </span>{&apos;capital&apos;: &apos;berlin&apos;, &apos;population&apos;: 80.62}
# </div>

# %%
europe_cap_pop['germany']['capital']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">48</span><span class="ansired">]: </span>&apos;berlin&apos;
# </div>

# %% [markdown]
# __Exercise__: Using the dictionaries created above:
# - Retrieve the second city listed for Spain in `europe_cities`.
# - Retrieve the last city listed in `europe_cities` for France. Use the `-1` index.
# - Retrieve the capital of Norway from `europe_cap_pop`.

# %% [markdown]
# ## Manipulating Dictionaries

# %%
europe_cities = {'spain'  :['madrid', 'barcelona', 'seville', 'valencia'], 
                 'france' :['paris', 'marseille', 'bordeaux'], 
                 'germany':['berlin', 'munich'], 
                 'norway' :['oslo'] }
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Add a new key-value pair to a dictionary.

# %%
europe_cities['italy'] = ['genoa']
europe_cities
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">50</span><span class="ansired">]: </span>
# {&apos;norway&apos;: [&apos;oslo&apos;],
#  &apos;italy&apos;: [&apos;genoa&apos;],
#  &apos;france&apos;: [&apos;paris&apos;, &apos;marseille&apos;, &apos;bordeaux&apos;],
#  &apos;spain&apos;: [&apos;madrid&apos;, &apos;barcelona&apos;, &apos;seville&apos;, &apos;valencia&apos;],
#  &apos;germany&apos;: [&apos;berlin&apos;, &apos;munich&apos;]}
# </div>

# %% [markdown]
# Append a string to the list stored as a value of a key.

# %%
europe_cities['norway'].append('bergen')
europe_cities
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">51</span><span class="ansired">]: </span>
# {&apos;norway&apos;: [&apos;oslo&apos;, &apos;bergen&apos;],
#  &apos;italy&apos;: [&apos;genoa&apos;],
#  &apos;france&apos;: [&apos;paris&apos;, &apos;marseille&apos;, &apos;bordeaux&apos;],
#  &apos;spain&apos;: [&apos;madrid&apos;, &apos;barcelona&apos;, &apos;seville&apos;, &apos;valencia&apos;],
#  &apos;germany&apos;: [&apos;berlin&apos;, &apos;munich&apos;]}
# </div>

# %% [markdown]
# ## Methods of Dictionaries

# %% [markdown]
# There are three basic methods used with dictionaries:
# 1. `keys` which returns the keys of all key-value pairs
# 1. `items` which returns the all key-value pairs as tuples
# 1. `get` which when passed a key return the corresponding value

# %% [markdown]
# The `keys()` method returns a list  containing the key names of the input dictionary.

# %%
{'a':1, 'b':2}.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">52</span><span class="ansired">]: </span>dict_keys([&apos;a&apos;, &apos;b&apos;])
# </div>

# %%
europe_cities.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">53</span><span class="ansired">]: </span>dict_keys([&apos;norway&apos;, &apos;italy&apos;, &apos;france&apos;, &apos;spain&apos;, &apos;germany&apos;])
# </div>

# %% [markdown]
# The `items()` method returns a list of tuples where each tuple contains the key name and its value.

# %%
{'a':1, 'b':2, 'c':3}.items()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">54</span><span class="ansired">]: </span>dict_items([(&apos;c&apos;, 3), (&apos;a&apos;, 1), (&apos;b&apos;, 2)])
# </div>

# %%
europe_cities.items()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">55</span><span class="ansired">]: </span>dict_items([(&apos;norway&apos;, [&apos;oslo&apos;, &apos;bergen&apos;]), (&apos;italy&apos;, [&apos;genoa&apos;]), (&apos;france&apos;, [&apos;paris&apos;, &apos;marseille&apos;, &apos;bordeaux&apos;]), (&apos;spain&apos;, [&apos;madrid&apos;, &apos;barcelona&apos;, &apos;seville&apos;, &apos;valencia&apos;]), (&apos;germany&apos;, [&apos;berlin&apos;, &apos;munich&apos;])])
# </div>

# %% [markdown]
# These `dict_items` can be transformed into a list.

# %%
list({'a':1, 'b':2}.items())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">56</span><span class="ansired">]: </span>[(&apos;a&apos;, 1), (&apos;b&apos;, 2)]
# </div>

# %% [markdown]
# The `get()` method returns the value of the key given as input (to the method.)

# %%
{'a':1, 'b':2}.get('b')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">57</span><span class="ansired">]: </span>2
# </div>

# %%
{'a':1, 'b':2}.get('c')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Below the `get` method attempts to retrieve the value of a key that is not present.
#
# In this case the second parameter is returned.

# %%
{'a':1, 'b':2}.get('z',"NA")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">61</span><span class="ansired">]: </span>&apos;NA&apos;
# </div>

# %% [markdown]
# __The End__

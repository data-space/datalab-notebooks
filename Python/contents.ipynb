# %% [markdown]
# # Contents - Python Essentials

# %% [markdown]
# List of notebooks in this folder with links:
# - `1.0 Basics` [Databricks](https://bentley.cloud.databricks.com/#notebook/90445)
# - `2.1 Lists` [Databricks](https://bentley.cloud.databricks.com/#notebook/90524)
# - `2.2 Tuples` [Databricks](https://bentley.cloud.databricks.com/#notebook/90494)
# - `2.3 Dictionaries` [Databricks](https://bentley.cloud.databricks.com/#notebook/90420)
# - `2.4 JSON` [Databricks](https://bentley.cloud.databricks.com/#notebook/858024)
# - `3.1 Comprehensions` [Databricks](https://bentley.cloud.databricks.com/#notebook/90595)
# - `3.2 Map, Filter, Reduce` [Databricks](https://bentley.cloud.databricks.com/#notebook/90384)
# - `3.3 Functions` [Databricks](https://bentley.cloud.databricks.com/#notebook/90341)
# - `4.1 Objects` [Databricks](https://bentley.cloud.databricks.com/#notebook/90404)
# - `4.2 Classes` [Databricks](https://bentley.cloud.databricks.com/#notebook/191802)
# - `6.1 Packages` [Databricks](https://bentley.cloud.databricks.com/#notebook/90573)
# - `7.1 Pipelines` [Databricks](https://bentley.cloud.databricks.com/#notebook/409455)
# - `7.2 Transformers` [Databricks](https://bentley.cloud.databricks.com/#notebook/430288)
# - `8.0 Exceptions` [Databricks](https://bentley.cloud.databricks.com/#notebook/90515)
#
# Note: these "Databricks" links are for internal Bentley users.

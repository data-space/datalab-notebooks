# %% [markdown]
# # Read data files - `pandas`

# %% [markdown]
# This notebook demonstrates the `read_csv`, `read_excel`, and `read_json` functions from pandas.

# %% [markdown]
# ## Contents
# 1. Setup
# 1. `read_csv` & fixing errors
# 1. `read_excel`
# 1. `read_json`

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# Load the `pandas` Python library.

# %%
# %python
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sh ls -hot /dbfs/mnt/datalab-datasets/538_data/mad-men
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 0
# -rw-r--r-- 1 root 8.0K Sep 18 11:46 performer-scores.csv
# -rw-r--r-- 1 root 1.9K Sep 18 11:46 README.md
# -rw-r--r-- 1 root  35K Sep 18 11:46 show-data.csv
# </div>

# %%
# %sh ls -hot /dbfs/mnt/datalab-datasets/538_data/mad-men/*
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-rw-r--r-- 1 root 8.0K Sep 18 11:46 /dbfs/mnt/datalab-datasets/538_data/mad-men/performer-scores.csv
# -rw-r--r-- 1 root 1.9K Sep 18 11:46 /dbfs/mnt/datalab-datasets/538_data/mad-men/README.md
# -rw-r--r-- 1 root  35K Sep 18 11:46 /dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv
# </div>

# %% [markdown]
# Notice that the output above changes if the asterisk is removed/included in the filepath of the `ls` command.
#
# The asterisk is required in order to produce a vector of full filepaths.

# %% [markdown]
# ## 2. `read_csv` & fixing errors

# %% [markdown]
# Attempt to read the `show-data.csv` file with the pandas `read_csv` function.
#
# It produces an error, which we will fix below.

# %%
# %python # error encountered
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv')
mad_men_show_data_pdf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">UnicodeDecodeError</span>                        Traceback (most recent call last)
# <span class="ansigreen">&lt;command-569009&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansired"># error encountered</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 2</span><span class="ansiyellow"> </span>mad_men_show_data_pdf <span class="ansiyellow">=</span> pd<span class="ansiyellow">.</span>read_csv<span class="ansiyellow">(</span><span class="ansiblue">&apos;/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">      3</span> mad_men_show_data_pdf<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    644</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    645</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 646</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    647</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    648</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    399</span>         <span class="ansigreen">return</span> parser<span class="ansiyellow"></span>
# <span class="ansigreen">    400</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 401</span><span class="ansiyellow">     </span>data <span class="ansiyellow">=</span> parser<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    402</span>     parser<span class="ansiyellow">.</span>close<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    403</span>     <span class="ansigreen">return</span> data<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">    937</span>                 <span class="ansigreen">raise</span> ValueError<span class="ansiyellow">(</span><span class="ansiblue">&apos;skipfooter not supported for iteration&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    938</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 939</span><span class="ansiyellow">         </span>ret <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_engine<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    940</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    941</span>         <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>options<span class="ansiyellow">.</span>get<span class="ansiyellow">(</span><span class="ansiblue">&apos;as_recarray&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">   1506</span>     <span class="ansigreen">def</span> read<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> nrows<span class="ansiyellow">=</span><span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1507</span>         <span class="ansigreen">try</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1508</span><span class="ansiyellow">             </span>data <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_reader<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1509</span>         <span class="ansigreen">except</span> StopIteration<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1510</span>             <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>_first_chunk<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader.read (pandas/parser.c:9977)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_low_memory (pandas/parser.c:10235)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_rows (pandas/parser.c:11254)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_column_data (pandas/parser.c:12629)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_tokens (pandas/parser.c:13505)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_with_dtype (pandas/parser.c:15381)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <spa

# %% [markdown]
# Notice the error above is also repeat below when simply displaying the file with the `cat` command.

# %%
# %sh # error encountered
cat /dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">UnicodeDecodeError</span>                        Traceback (most recent call last)
# <span class="ansigreen">&lt;command-569018&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">     17</span>         <span class="ansigreen">if</span> returncode <span class="ansiyellow">!=</span> <span class="ansicyan">0</span> <span class="ansigreen">and</span> <span class="ansigreen">False</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">     18</span>             <span class="ansigreen">raise</span> subprocess<span class="ansiyellow">.</span>CalledProcessError<span class="ansiyellow">(</span>returncode<span class="ansiyellow">,</span> cmd<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 19</span><span class="ansiyellow">     </span>____databricks_percent_sh<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     20</span> <span class="ansigreen">finally</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">     21</span>     <span class="ansigreen">del</span> ____databricks_percent_sh<span class="ansiyellow"></span>
#
# <span class="ansigreen">&lt;command-569018&gt;</span> in <span class="ansicyan">____databricks_percent_sh</span><span class="ansiblue">()</span>
# <span class="ansigreen">     11</span>             stdout <span class="ansiyellow">=</span> subprocess<span class="ansiyellow">.</span>PIPE<span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">     12</span>             universal_newlines = True)
# <span class="ansigreen">---&gt; 13</span><span class="ansiyellow">         </span><span class="ansigreen">for</span> line <span class="ansigreen">in</span> iter<span class="ansiyellow">(</span>p<span class="ansiyellow">.</span>stdout<span class="ansiyellow">.</span>readline<span class="ansiyellow">,</span> <span class="ansiblue">&apos;&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">     14</span>             sys<span class="ansiyellow">.</span>stdout<span class="ansiyellow">.</span>write<span class="ansiyellow">(</span>line<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     15</span>             sys<span class="ansiyellow">.</span>stdout<span class="ansiyellow">.</span>flush<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/codecs.py</span> in <span class="ansicyan">decode</span><span class="ansiblue">(self, input, final)</span>
# <span class="ansigreen">    319</span>         <span class="ansired"># decode input (taking the buffer into account)</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">    320</span>         data <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>buffer <span class="ansiyellow">+</span> input<span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 321</span><span class="ansiyellow">         </span><span class="ansiyellow">(</span>result<span class="ansiyellow">,</span> consumed<span class="ansiyellow">)</span> <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_buffer_decode<span class="ansiyellow">(</span>data<span class="ansiyellow">,</span> self<span class="ansiyellow">.</span>errors<span class="ansiyellow">,</span> final<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    322</span>         <span class="ansired"># keep undecoded input until the next call</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">    323</span>         self<span class="ansiyellow">.</span>buffer <span class="ansiyellow">=</span> data<span class="ansiyellow">[</span>consumed<span class="ansiyellow">:</span><span class="ansiyellow">]</span><span class="ansiyellow"></span>
#
# <span class="ansired">UnicodeDecodeError</span>: &apos;utf-8&apos; codec can&apos;t decode byte 0xd5 in position 3032: invalid continuation byte</div>

# %% [markdown]
# In this case, when encountering an unknown error, I search for posts about the error on Google.
#
# Search for: "read_csv pandas UnicodeDecodeError utf-8 codec can't decode byte  in position invalid continuation byte".
#
# Notice I added "read_csv" and "pandas" to the search string.
# I removed `0xd5` and `3032` as these are specific to our file and won't help the search find other posts that solve the same problem, but with a different file.
#
# The search found: https://stackoverflow.com/questions/18171739/unicodedecodeerror-when-reading-csv-file-in-pandas-with-python
#
# This links suggests trying `encoding = "ISO-8859-1"` as a parameter to `read_csv` (it works, see below)

# %%
# %python
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
# Performer        248 non-null object
# Show             248 non-null object
# Show Start       248 non-null int64
# Show End         248 non-null object
# Status?          248 non-null object
# CharEnd          248 non-null int64
# Years Since      248 non-null int64
# #LEAD            248 non-null int64
# #SUPPORT         248 non-null int64
# #Shows           248 non-null int64
# Score            248 non-null float64
# Score/Y          248 non-null object
# lead_notes       89 non-null object
# support_notes    135 non-null object
# show_notes       138 non-null object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 29.1+ KB
# </div>

# %% [markdown]
# The command did work.
#
# Notice the column names have non-alphabetic characters (including spaces).
# The next step is to read in the columns with better names.

# %% [markdown]
# The names parameter specifies the column names to use (in the dataframe returned by `read_csv`).

# %%
# %python
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                           'status', 'char_end', 'years_since', 'lead', 
                                           'support', 'shows', 'score', 'score_y',
                                           'lead_notes', 'support_notes', 'show_notes'],
                                    header=0, 
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
# performer        248 non-null object
# show             248 non-null object
# show_start       248 non-null int64
# show_end         248 non-null object
# status           248 non-null object
# char_end         248 non-null int64
# years_since      248 non-null int64
# lead             248 non-null int64
# support          248 non-null int64
# shows            248 non-null int64
# score            248 non-null float64
# score_y          248 non-null object
# lead_notes       89 non-null object
# support_notes    135 non-null object
# show_notes       138 non-null object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 29.1+ KB
# </div>

# %% [markdown]
# Notice the column names are better, but that we needed to specify, with the `header` parameter, that row `0` containes the column names.

# %% [markdown]
# The column types are in the right hand column of the output from the `info` method.
# If a column is read in as a `float64` or `int64` then we can assume it was read correctly.
#
# To check for columns that were not read correctly we only need to select columns with `object` type.
# The next command does this.

# %%
mad_men_show_data_pdf \
  .select_dtypes(include=['object']) \
  .head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>
#           performer          show show_end status      score_y  \
# 0       Steven Hill   Law &amp; Order     2010    END            0
# 1    Kelli Williams  The Practice     2014    END  0.520833333
# 2  LisaGay Hamilton  The Practice     2014    END  0.333333333
# 3  Lara Flynn Boyle  The Practice     2014    END            0
# 4   Dylan McDermott  The Practice     2014    END  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# 2  Life of a King, 2014; Go For Sisters, 2013
# 3                                         NaN
# 4     Olympus Has Fallen, 2013; Freezer, 2014
#
#                                        support_notes  \
# 0                                                NaN
# 1                                 Any Day Now (2012)
# 2                                                NaN
# 3                                                NaN
# 4  The Messengers, 2007; Unbeatable Harold, 2009;...
#
#                                           show_notes
# 0                                                NaN
# 1  Medical Investigation, Season 1; Lie To Me, Se...
# 2                   Men of a Certain Age, Season 1-2
# 3                                                NaN
# 4  Big Shots, Season 1; Dark Blue, Season 1-2; Am...
# </div>

# %% [markdown]
# Notice that `show_end` and `score_y` should be numbers.
#
# The following command specifies both `show_start` and `show_end` as integers. We leave `score_y` until later.

# %%
# %python # error encountered
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                             'status', 'char_end', 'years_since', 'lead', 
                                             'support', 'shows', 'score', 'score_y',
                                             'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.int64, 'show_end': np.int64},
                                    header=0, 
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ValueError</span>                                Traceback (most recent call last)
# <span class="ansigreen">&lt;command-575162&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      8</span>                                     dtype<span class="ansiyellow">=</span><span class="ansiyellow">{</span><span class="ansiblue">&apos;show_start&apos;</span><span class="ansiyellow">:</span> np<span class="ansiyellow">.</span>int64<span class="ansiyellow">,</span> <span class="ansiblue">&apos;show_end&apos;</span><span class="ansiyellow">:</span> np<span class="ansiyellow">.</span>int64<span class="ansiyellow">}</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">      9</span>                                     header<span class="ansiyellow">=</span><span class="ansicyan">0</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 10</span><span class="ansiyellow">                                     encoding = &apos;ISO-8859-1&apos;)
# </span><span class="ansigreen">     11</span> mad_men_show_data_pdf<span class="ansiyellow">.</span>info<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    644</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    645</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 646</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    647</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    648</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    399</span>         <span class="ansigreen">return</span> parser<span class="ansiyellow"></span>
# <span class="ansigreen">    400</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 401</span><span class="ansiyellow">     </span>data <span class="ansiyellow">=</span> parser<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    402</span>     parser<span class="ansiyellow">.</span>close<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    403</span>     <span class="ansigreen">return</span> data<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">    937</span>                 <span class="ansigreen">raise</span> ValueError<span class="ansiyellow">(</span><span class="ansiblue">&apos;skipfooter not supported for iteration&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    938</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 939</span><span class="ansiyellow">         </span>ret <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_engine<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    940</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    941</span>         <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>options<span class="ansiyellow">.</span>get<span class="ansiyellow">(</span><span class="ansiblue">&apos;as_recarray&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">   1506</span>     <span class="ansigreen">def</span> read<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> nrows<span class="ansiyellow">=</span><span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1507</span>         <span class="ansigreen">try</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1508</span><span class="ansiyellow">             </span>data <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_reader<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1509</span>         <span class="ansigreen">except</span> StopIteration<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1510</span>             <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>_first_chunk<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader.read (pandas/parser.c:9977)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_low_memory (pandas/parser.c:10235)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_rows (pandas/parser.c:11254)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_column_data (pandas/parser.c:12629)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._conv

# %% [markdown]
# An error is encountered, indicating that `PRESENT` is an invalid value for an integer.
#
# So we specify `PRESENT` to indicate a missing value. This should work.

# %%
# %python
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                             'status', 'char_end', 'years_since', 'lead', 
                                             'support', 'shows', 'score', 'score_y',
                                             'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.int64, 'show_end': np.int64, 'score_y': np.float64},
                                    header=0, 
                                    na_values=['PRESENT'],
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ValueError</span>                                Traceback (most recent call last)
# <span class="ansigreen">&lt;command-575165&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      8</span>                                     header<span class="ansiyellow">=</span><span class="ansicyan">0</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">      9</span>                                     na_values<span class="ansiyellow">=</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;PRESENT&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 10</span><span class="ansiyellow">                                     encoding = &apos;ISO-8859-1&apos;)
# </span><span class="ansigreen">     11</span> mad_men_show_data_pdf<span class="ansiyellow">.</span>info<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    644</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    645</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 646</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    647</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    648</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    399</span>         <span class="ansigreen">return</span> parser<span class="ansiyellow"></span>
# <span class="ansigreen">    400</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 401</span><span class="ansiyellow">     </span>data <span class="ansiyellow">=</span> parser<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    402</span>     parser<span class="ansiyellow">.</span>close<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    403</span>     <span class="ansigreen">return</span> data<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">    937</span>                 <span class="ansigreen">raise</span> ValueError<span class="ansiyellow">(</span><span class="ansiblue">&apos;skipfooter not supported for iteration&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    938</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 939</span><span class="ansiyellow">         </span>ret <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_engine<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    940</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    941</span>         <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>options<span class="ansiyellow">.</span>get<span class="ansiyellow">(</span><span class="ansiblue">&apos;as_recarray&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">   1506</span>     <span class="ansigreen">def</span> read<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> nrows<span class="ansiyellow">=</span><span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1507</span>         <span class="ansigreen">try</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1508</span><span class="ansiyellow">             </span>data <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_reader<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1509</span>         <span class="ansigreen">except</span> StopIteration<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1510</span>             <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>_first_chunk<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader.read (pandas/parser.c:9977)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_low_memory (pandas/parser.c:10235)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_rows (pandas/parser.c:11254)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_column_data (pandas/parser.c:12629)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_tokens (pandas/parser.c:13296)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas

# %% [markdown]
# But this does not work. So we check Google again for the error.

# %% [markdown]
# Searching for "ValueError: Integer column has NA values in column 3" yields this link:
# - https://stackoverflow.com/questions/21287624/convert-pandas-column-containing-nans-to-dtype-int
#
# The post indicates that integers cannot have missing values in pandas and that they should be retyped to `np.float32`.
# Both columns (`show_start` and `show_end`) where coding this way for consistency.
# It's awkward, but it works.

# %%
# %python
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                           'status', 'char_end', 'years_since', 'lead', 
                                           'support', 'shows', 'score', 'score_y',
                                           'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.float32, 'show_end': np.float32},
                                    header=0, 
                                    na_values=['PRESENT'],
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
# performer        248 non-null object
# show             248 non-null object
# show_start       248 non-null float32
# show_end         219 non-null float32
# status           248 non-null object
# char_end         248 non-null int64
# years_since      248 non-null int64
# lead             248 non-null int64
# support          248 non-null int64
# shows            248 non-null int64
# score            248 non-null float64
# score_y          248 non-null object
# lead_notes       89 non-null object
# support_notes    135 non-null object
# show_notes       138 non-null object
# dtypes: float32(2), float64(1), int64(5), object(7)
# memory usage: 27.2+ KB
# </div>

# %% [markdown]
# Recall that`score_y` should be a `float`. The command below specifies this in the `dtype` parameter.

# %%
# %python
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                           'status', 'char_end', 'years_since', 'lead', 
                                           'support', 'shows', 'score', 'score_y',
                                           'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.float32, 
                                           'show_end': np.float32,
                                           'score_y': np.float32},
                                    header=0, 
                                    na_values=['PRESENT'],
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ValueError</span>                                Traceback (most recent call last)
# <span class="ansigreen">&lt;command-858154&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">     10</span>                                     header<span class="ansiyellow">=</span><span class="ansicyan">0</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">     11</span>                                     na_values<span class="ansiyellow">=</span><span class="ansiyellow">[</span><span class="ansiblue">&apos;PRESENT&apos;</span><span class="ansiyellow">]</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 12</span><span class="ansiyellow">                                     encoding = &apos;ISO-8859-1&apos;)
# </span><span class="ansigreen">     13</span> mad_men_show_data_pdf<span class="ansiyellow">.</span>info<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">parser_f</span><span class="ansiblue">(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)</span>
# <span class="ansigreen">    644</span>                     skip_blank_lines=skip_blank_lines)
# <span class="ansigreen">    645</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 646</span><span class="ansiyellow">         </span><span class="ansigreen">return</span> _read<span class="ansiyellow">(</span>filepath_or_buffer<span class="ansiyellow">,</span> kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    647</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    648</span>     parser_f<span class="ansiyellow">.</span>__name__ <span class="ansiyellow">=</span> name<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_read</span><span class="ansiblue">(filepath_or_buffer, kwds)</span>
# <span class="ansigreen">    399</span>         <span class="ansigreen">return</span> parser<span class="ansiyellow"></span>
# <span class="ansigreen">    400</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 401</span><span class="ansiyellow">     </span>data <span class="ansiyellow">=</span> parser<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    402</span>     parser<span class="ansiyellow">.</span>close<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    403</span>     <span class="ansigreen">return</span> data<span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">    937</span>                 <span class="ansigreen">raise</span> ValueError<span class="ansiyellow">(</span><span class="ansiblue">&apos;skipfooter not supported for iteration&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    938</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 939</span><span class="ansiyellow">         </span>ret <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_engine<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    940</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    941</span>         <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>options<span class="ansiyellow">.</span>get<span class="ansiyellow">(</span><span class="ansiblue">&apos;as_recarray&apos;</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">read</span><span class="ansiblue">(self, nrows)</span>
# <span class="ansigreen">   1506</span>     <span class="ansigreen">def</span> read<span class="ansiyellow">(</span>self<span class="ansiyellow">,</span> nrows<span class="ansiyellow">=</span><span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1507</span>         <span class="ansigreen">try</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1508</span><span class="ansiyellow">             </span>data <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_reader<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span>nrows<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1509</span>         <span class="ansigreen">except</span> StopIteration<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1510</span>             <span class="ansigreen">if</span> self<span class="ansiyellow">.</span>_first_chunk<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader.read (pandas/parser.c:9977)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_low_memory (pandas/parser.c:10235)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._read_rows (pandas/parser.c:11254)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_column_data (pandas/parser.c:12629)</span><span class="ansiblue">()</span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/parser.cpython-35m-x86_64-linux-gnu.so</span> in <span class="ansicyan">pandas.parser.TextReader._convert_tokens (pandas/parser.c:13876)</span><span class="ansiblue">()</span>
#
# <span class="ansired">ValueError</span>: could not convert string to float: &apos;#DIV/0!&apos;</div>

# %% [markdown]
# The error indicates that `#DIV/0!` is a value in the `score_y` field. So this value is included in the `na_values` parameter (below).

# %%
# %python
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                           'status', 'char_end', 'years_since', 'lead', 
                                           'support', 'shows', 'score', 'score_y',
                                           'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.float32, 
                                           'show_end': np.float32,
                                           'score_y': np.float32},
                                    header=0, 
                                    na_values=['PRESENT','#DIV/0!'],
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
# performer        248 non-null object
# show             248 non-null object
# show_start       248 non-null float32
# show_end         219 non-null float32
# status           248 non-null object
# char_end         248 non-null int64
# years_since      248 non-null int64
# lead             248 non-null int64
# support          248 non-null int64
# shows            248 non-null int64
# score            248 non-null float64
# score_y          245 non-null float32
# lead_notes       89 non-null object
# support_notes    135 non-null object
# show_notes       138 non-null object
# dtypes: float32(3), float64(1), int64(5), object(6)
# memory usage: 26.2+ KB
# </div>

# %% [markdown]
# Great. All columns are read with acceptable datatypes. The following command displays the first few records for `object` columns.

# %%
# %python
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                           'status', 'char_end', 'years_since', 'lead', 
                                           'support', 'shows', 'score', 'score_y',
                                           'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.float32, 
                                           'show_end': np.float32,
                                           'score_y': np.float32},
                                    header=0, 
                                    na_values=['PRESENT','#DIV/0!'],
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf \
  .select_dtypes(include=['object']) \
  .head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">49</span><span class="ansired">]: </span>
#           performer          show status  \
# 0       Steven Hill   Law &amp; Order    END
# 1    Kelli Williams  The Practice    END
# 2  LisaGay Hamilton  The Practice    END
# 3  Lara Flynn Boyle  The Practice    END
# 4   Dylan McDermott  The Practice    END
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# 2  Life of a King, 2014; Go For Sisters, 2013
# 3                                         NaN
# 4     Olympus Has Fallen, 2013; Freezer, 2014
#
#                                        support_notes  \
# 0                                                NaN
# 1                                 Any Day Now (2012)
# 2                                                NaN
# 3                                                NaN
# 4  The Messengers, 2007; Unbeatable Harold, 2009;...
#
#                                           show_notes
# 0                                                NaN
# 1  Medical Investigation, Season 1; Lie To Me, Se...
# 2                   Men of a Certain Age, Season 1-2
# 3                                                NaN
# 4  Big Shots, Season 1; Dark Blue, Season 1-2; Am...
# </div>

# %% [markdown]
# One final modification is to check on the `status` column. It is likely that it should have datatype of `category`.
#
# First, check the unique values of this column.

# %%
mad_men_show_data_pdf.status.value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">50</span><span class="ansired">]: </span>
# END     202
# LEFT     29
# End      17
# Name: status, dtype: int64
# </div>

# %% [markdown]
# Now change the datatype for the `status` column with the `dtype` parameter.

# %%
# %python
import numpy as np
mad_men_show_data_pdf = pd.read_csv('/dbfs/mnt/datalab-datasets/538_data/mad-men/show-data.csv', 
                                    names=['performer', 'show', 'show_start', 'show_end',
                                           'status', 'char_end', 'years_since', 'lead', 
                                           'support', 'shows', 'score', 'score_y',
                                           'lead_notes', 'support_notes', 'show_notes'],
                                    dtype={'show_start': np.float32, 
                                           'show_end': np.float32,
                                           'score_y': np.float32,
                                           'status': 'category'},
                                    header=0, 
                                    na_values=['PRESENT','#DIV/0!'],
                                    encoding = 'ISO-8859-1')
mad_men_show_data_pdf \
  .info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 15 columns):
# performer        248 non-null object
# show             248 non-null object
# show_start       248 non-null float32
# show_end         219 non-null float32
# status           248 non-null category
# char_end         248 non-null int64
# years_since      248 non-null int64
# lead             248 non-null int64
# support          248 non-null int64
# shows            248 non-null int64
# score            248 non-null float64
# score_y          245 non-null float32
# lead_notes       89 non-null object
# support_notes    135 non-null object
# show_notes       138 non-null object
# dtypes: category(1), float32(3), float64(1), int64(5), object(5)
# memory usage: 24.6+ KB
# </div>

# %% [markdown]
# Great. Now, all columns really are read with acceptable datatypes.

# %% [markdown]
# ## 3. `read_excel`

# %% [markdown]
# List the spreadsheets in the `per_diem` directory.

# %%
# %sh ls -hot /dbfs/mnt/datalab-datasets/per_diem/*.xls
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-rw-r--r-- 1 root 257K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/April2017PD.xls
# -rw-r--r-- 1 root 242K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/April2018PD.xls
# -rw-r--r-- 1 root 246K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/August2017PD.xls
# -rw-r--r-- 1 root 238K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/December2017PD.xls
# -rw-r--r-- 1 root 263K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/February2017PD.xls
# -rw-r--r-- 1 root 240K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/February2018PD.xls
# -rw-r--r-- 1 root 251K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/January2017PD.xls
# -rw-r--r-- 1 root 233K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/January2018PD.xls
# -rw-r--r-- 1 root 241K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/July2017PD.xls
# -rw-r--r-- 1 root 259K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/July2018PD.xls
# -rw-r--r-- 1 root 250K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/June2017PD.xls
# -rw-r--r-- 1 root 253K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/June2018PD.xls
# -rw-r--r-- 1 root 249K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/March2017PD.xls
# -rw-r--r-- 1 root 242K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/March2018PD.xls
# -rw-r--r-- 1 root 257K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls
# -rw-r--r-- 1 root 256K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/May2018PD.xls
# -rw-r--r-- 1 root 237K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/November2017PD.xls
# -rw-r--r-- 1 root 237K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/October2017PD.xls
# -rw-r--r-- 1 root 242K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/September2017PD.xls
# -rw-r--r-- 1 root 245K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/September2018PD.xls
# -rw-r--r-- 1 root 253K Sep 18 12:15 /dbfs/mnt/datalab-datasets/per_diem/August2018PD.xls
# </div>

# %% [markdown]
# The following command uses the pandas function `read_excel` to read in the spreadsheet.

# %%
# %python
import pandas as pd
may_2017_pdf = pd.read_excel('/dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls')
may_2017_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING *** file size (262658) not 512 + multiple of sector size (512)
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 11 columns):
# Country Name           1105 non-null object
# Location               1105 non-null object
# Season Code            1105 non-null object
# Season Start Date      1105 non-null datetime64[ns]
# Season End Date        1105 non-null datetime64[ns]
# Lodging                1105 non-null int64
# Meals &amp; Incidentals    1105 non-null int64
# Per Diem               1105 non-null int64
# Effective Date         1105 non-null datetime64[ns]
# Footnote Reference     340 non-null object
# Location Code          1105 non-null int64
# dtypes: datetime64[ns](3), int64(4), object(4)
# memory usage: 95.0+ KB
# </div>

# %% [markdown]
# Notice the column names (they are in mixed case and contain spaces) and notice the columns with type `object`.
#
# We fix the column names with the `names` parameter.

# %%
# %python
import pandas as pd
may_2017_pdf = pd.read_excel('/dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls',
                             names=['country_name', 'location', 'season_code', 'season_start_date', 
                                    'season_end_date', 'lodging', 'meals_incidentals', 'per_diem', 
                                    'effective_date', 'footnote_reference', 'location_code']
                            )
may_2017_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING *** file size (262658) not 512 + multiple of sector size (512)
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 11 columns):
# country_name          1105 non-null object
# location              1105 non-null object
# season_code           1105 non-null object
# season_start_date     1105 non-null datetime64[ns]
# season_end_date       1105 non-null datetime64[ns]
# lodging               1105 non-null int64
# meals_incidentals     1105 non-null int64
# per_diem              1105 non-null int64
# effective_date        1105 non-null datetime64[ns]
# footnote_reference    340 non-null object
# location_code         1105 non-null int64
# dtypes: datetime64[ns](3), int64(4), object(4)
# memory usage: 95.0+ KB
# </div>

# %%
may_2017_pdf \
  .select_dtypes(include=['object']) \
  .head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>
#   country_name location season_code footnote_reference
# 0  AFGHANISTAN  [Other]          S1               19,2
# 1  AFGHANISTAN    Kabul          S1               19,2
# 2      ALBANIA  [Other]          S1                NaN
# 3      ALBANIA   Tirana          S1                NaN
# 4      ALGERIA  [Other]          S1                  2
# </div>

# %% [markdown]
# The first three columns should have datatype `category`. Make is so number 1.

# %%
# %python
import pandas as pd
may_2017_pdf = pd.read_excel('/dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls',
                             names=['country_name', 'location', 'season_code', 'season_start_date', 
                                    'season_end_date', 'lodging', 'meals_incidentals', 'per_diem', 
                                    'effective_date', 'footnote_reference', 'location_code'],
                             dtypes={'country_name': 'category',
                                     'location': 'category',
                                     'season_code': 'category'}
                            )
may_2017_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING *** file size (262658) not 512 + multiple of sector size (512)
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 11 columns):
# country_name          1105 non-null object
# location              1105 non-null object
# season_code           1105 non-null object
# season_start_date     1105 non-null datetime64[ns]
# season_end_date       1105 non-null datetime64[ns]
# lodging               1105 non-null int64
# meals_incidentals     1105 non-null int64
# per_diem              1105 non-null int64
# effective_date        1105 non-null datetime64[ns]
# footnote_reference    340 non-null object
# location_code         1105 non-null int64
# dtypes: datetime64[ns](3), int64(4), object(4)
# memory usage: 95.0+ KB
# </div>

# %% [markdown]
# Unfortunately, the `dtypes` parameter didn't work.

# %%
# %python
import pandas as pd
may_2017_pdf = pd.read_excel('/dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls',
                             names=['country_name', 'location', 'season_code', 'season_start_date', 
                                    'season_end_date', 'lodging', 'meals_incidentals', 'per_diem', 
                                    'effective_date', 'footnote_reference', 'location_code'],
                             dtype={'country_name': 'category',
                                     'location': 'category',
                                     'season_code': 'category'}
                            )
may_2017_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ValueError</span>                                Traceback (most recent call last)
# <span class="ansigreen">&lt;command-858169&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      6</span>                              dtype={&apos;country_name&apos;: &apos;category&apos;,
# <span class="ansigreen">      7</span>                                      <span class="ansiblue">&apos;location&apos;</span><span class="ansiyellow">:</span> <span class="ansiblue">&apos;category&apos;</span><span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">----&gt; 8</span><span class="ansiyellow">                                      &apos;season_code&apos;: &apos;category&apos;}
# </span><span class="ansigreen">      9</span>                             )
# <span class="ansigreen">     10</span> may_2017_pdf<span class="ansiyellow">.</span>info<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/excel.py</span> in <span class="ansicyan">read_excel</span><span class="ansiblue">(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, true_values, false_values, engine, squeeze, **kwds)</span>
# <span class="ansigreen">    198</span>         skip_footer<span class="ansiyellow">=</span>skip_footer<span class="ansiyellow">,</span> converters<span class="ansiyellow">=</span>converters<span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">    199</span>         true_values<span class="ansiyellow">=</span>true_values<span class="ansiyellow">,</span> false_values<span class="ansiyellow">=</span>false_values<span class="ansiyellow">,</span> squeeze<span class="ansiyellow">=</span>squeeze<span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 200</span><span class="ansiyellow">         **kwds)
# </span><span class="ansigreen">    201</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    202</span> <span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/excel.py</span> in <span class="ansicyan">_parse_excel</span><span class="ansiblue">(self, sheetname, header, skiprows, names, skip_footer, index_col, has_index_names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, true_values, false_values, verbose, squeeze, **kwds)</span>
# <span class="ansigreen">    502</span>                                     skipfooter<span class="ansiyellow">=</span>skip_footer<span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">    503</span>                                     squeeze<span class="ansiyellow">=</span>squeeze<span class="ansiyellow">,</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 504</span><span class="ansiyellow">                                     **kwds)
# </span><span class="ansigreen">    505</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    506</span>                 output<span class="ansiyellow">[</span>asheetname<span class="ansiyellow">]</span> <span class="ansiyellow">=</span> parser<span class="ansiyellow">.</span>read<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">TextParser</span><span class="ansiblue">(*args, **kwds)</span>
# <span class="ansigreen">   1669</span>     &quot;&quot;&quot;
# <span class="ansigreen">   1670</span>     kwds<span class="ansiyellow">[</span><span class="ansiblue">&apos;engine&apos;</span><span class="ansiyellow">]</span> <span class="ansiyellow">=</span> <span class="ansiblue">&apos;python&apos;</span><span class="ansiyellow"></span>
# <span class="ansigreen">-&gt; 1671</span><span class="ansiyellow">     </span><span class="ansigreen">return</span> TextFileReader<span class="ansiyellow">(</span><span class="ansiyellow">*</span>args<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kwds<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1672</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1673</span> <span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">__init__</span><span class="ansiblue">(self, f, engine, **kwds)</span>
# <span class="ansigreen">    718</span>         self<span class="ansiyellow">.</span>_currow <span class="ansiyellow">=</span> <span class="ansicyan">0</span><span class="ansiyellow"></span>
# <span class="ansigreen">    719</span> <span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 720</span><span class="ansiyellow">         </span>options <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>_get_options_with_defaults<span class="ansiyellow">(</span>engine<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    721</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    722</span>         self<span class="ansiyellow">.</span>chunksize <span class="ansiyellow">=</span> options<span class="ansiyellow">.</span>pop<span class="ansiyellow">(</span><span class="ansiblue">&apos;chunksize&apos;</span><span class="ansiyellow">,</span> <span class="ansigreen">None</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/python/lib/python3.5/site-packages/pandas/io/parsers.py</span> in <span class="ansicyan">_get_options_with_defaults</span><span class="ansiblue">(self, engine)</span>
# <span class="ansigreen">    759</span>                         raise ValueError(
# <span class="ansigreen">    760</span>                             <span class="ansiblue">&apos;The %r option is not supported with the&apos;</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 761</span><span class="ansiyellow">                             &apos; %r engine&apos; % (argname, engine))
# </span><span class="ansigreen">    762</span>             <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    763</span>                 value <span class="ansiyellow">=</span> default<span class="ansiyellow"></span>
#
# <span class="ansired">ValueError</span>: The &apos;dtype&apos; option is not supported with the &apos;python&apos; engine</div>

# %% [markdown]
# Checking this message on Google reveals that we should use the `converters` parameter. See [stackoverflow](https://stackoverflow.com/questions/32591466/python-pandas-how-to-specify-data-types-when-reading-an-excel-file).
#
# Further checking [the documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html) reveals that the `dtype` parameter was added in version `0.20.0` and we are running `0.19.2`. (See below.)

# %%
pd.__version__
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>&apos;0.19.2&apos;
# </div>

# %% [markdown]
# There seems to be little documentation on the `converters` parameter.  Because of this I use the `assign` method to change the type of the column after reading the spreadsheet with `read_excel` as follows.

# %%
# %python
import pandas as pd
may_2017_pdf = \
pd.read_excel('/dbfs/mnt/datalab-datasets/per_diem/May2017PD.xls',
              names=['country_name', 'location', 'season_code', 'season_start_date', 
                     'season_end_date', 'lodging', 'meals_incidentals', 'per_diem', 
                     'effective_date', 'footnote_reference', 'location_code']
             ) \
  .assign(country_name=lambda df: df.country_name.astype('category'),
          location    =lambda df: df.location.astype('category'),
          season_code =lambda df: df.season_code.astype('category')
         )
        
may_2017_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING *** file size (262658) not 512 + multiple of sector size (512)
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 11 columns):
# country_name          1105 non-null category
# location              1105 non-null category
# season_code           1105 non-null category
# season_start_date     1105 non-null datetime64[ns]
# season_end_date       1105 non-null datetime64[ns]
# lodging               1105 non-null int64
# meals_incidentals     1105 non-null int64
# per_diem              1105 non-null int64
# effective_date        1105 non-null datetime64[ns]
# footnote_reference    340 non-null object
# location_code         1105 non-null int64
# dtypes: category(3), datetime64[ns](3), int64(4), object(1)
# memory usage: 83.2+ KB
# </div>

# %% [markdown]
# See the documentation on the `assign` method:
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.assign.html

# %% [markdown]
# Make one last check on the columns of type `object`.

# %%
# %python
may_2017_pdf \
  .select_dtypes(include=['object']) \
  .head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">28</span><span class="ansired">]: </span>
#   footnote_reference
# 0               19,2
# 1               19,2
# 2                NaN
# 3                NaN
# 4                  2
# </div>

# %% [markdown]
# That looks like a reasonable `object` column. The `may_2017_pdf` dataframe is ready to be analyzed.

# %% [markdown]
# ## 4. `read_json`

# %% [markdown]
# List the JSON files in the `/dbfs/mnt/datalab-datasets/JSON` directory.

# %%
# %sh ls -hot /dbfs/mnt/datalab-datasets/JSON
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 0
# -rw-r--r-- 1 root 2.9M Aug  7  2017 world_bank.json
# -rw-r--r-- 1 root 3.1M Aug  7  2017 zips.json
# -rw-r--r-- 1 root  11M Aug  7  2017 stocks.json
# -rw-r--r-- 1 root  16M Aug  7  2017 enron.json
# -rw-r--r-- 1 root  75M Aug  7  2017 companies.json
# </div>

# %% [markdown]
# The first example uses the `zips.json` file. It only contains three records, which are displayed below.

# %%
# %sh head -n 3 /dbfs/mnt/datalab-datasets/JSON/zips.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{ &quot;city&quot; : &quot;AGAWAM&quot;, &quot;loc&quot; : [ -72.622739, 42.070206 ], &quot;pop&quot; : 15338, &quot;state&quot; : &quot;MA&quot;, &quot;_id&quot; : &quot;01001&quot; }
# { &quot;city&quot; : &quot;CUSHMAN&quot;, &quot;loc&quot; : [ -72.51564999999999, 42.377017 ], &quot;pop&quot; : 36963, &quot;state&quot; : &quot;MA&quot;, &quot;_id&quot; : &quot;01002&quot; }
# { &quot;city&quot; : &quot;BARRE&quot;, &quot;loc&quot; : [ -72.10835400000001, 42.409698 ], &quot;pop&quot; : 4546, &quot;state&quot; : &quot;MA&quot;, &quot;_id&quot; : &quot;01005&quot; }
# </div>

# %% [markdown]
# Read the file using `read_json`. The `lines=True` parameter indicates that there should be one JSON object per line. These JSON objects correspond to rows/records. The key names correspond to column names.

# %%
# %python
zips_pdf = pd.read_json('/dbfs/mnt/datalab-datasets/JSON/zips.json',
                        lines=True)
zips_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# Int64Index: 29467 entries, 0 to 29466
# Data columns (total 5 columns):
# _id      29467 non-null int64
# city     29467 non-null object
# loc      29467 non-null object
# pop      29467 non-null int64
# state    29467 non-null object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ MB
# </div>

# %% [markdown]
# List the first five records of the dataframe. Notice the `loc` column. It seems to contain a list, but has the `object` datatype.

# %%
zips_pdf.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">41</span><span class="ansired">]: </span>
#     _id         city                      loc    pop state
# 0  1001       AGAWAM  [-72.622739, 42.070206]  15338    MA
# 1  1002      CUSHMAN   [-72.51565, 42.377017]  36963    MA
# 2  1005        BARRE  [-72.108354, 42.409698]   4546    MA
# 3  1007  BELCHERTOWN  [-72.410953, 42.275103]  10579    MA
# 4  1008    BLANDFORD  [-72.936114, 42.182949]   1240    MA
# </div>

# %%
# %python 
zips_pdf.loc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">42</span><span class="ansired">]: </span>&lt;pandas.core.indexing._LocIndexer at 0x7fc17ad69c18&gt;
# </div>

# %% [markdown]
# The `loc` indexer masks the `loc column` so it should be renamed. The `read_json` function has no `names` parameter so we use the `rename` method. See the documentation for details on the `rename` method:
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html

# %%
# %python
zips_pdf = \
pd.read_json('/dbfs/mnt/datalab-datasets/JSON/zips.json',
             lines=True) \
  .rename(columns={'loc':'lon_lat'})
zips_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# Int64Index: 29467 entries, 0 to 29466
# Data columns (total 5 columns):
# _id        29467 non-null int64
# city       29467 non-null object
# lon_lat    29467 non-null object
# pop        29467 non-null int64
# state      29467 non-null object
# dtypes: int64(2), object(3)
# memory usage: 1.3+ MB
# </div>

# %% [markdown]
# The `city` and `state` columns should have datatype `category`. The `dtype` parameter didn't work so the `assign` method is used.

# %%
# %python
zips_pdf = \
pd.read_json('/dbfs/mnt/datalab-datasets/JSON/zips.json',
             lines=True) \
  .rename(columns={'loc':'lon_lat'}) \
  .assign(city =lambda df: df.city .astype('category'),
          state=lambda df: df.state.astype('category')
         )

zips_pdf.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# Int64Index: 29467 entries, 0 to 29466
# Data columns (total 5 columns):
# _id        29467 non-null int64
# city       29467 non-null category
# lon_lat    29467 non-null object
# pop        29467 non-null int64
# state      29467 non-null category
# dtypes: category(2), int64(2), object(1)
# memory usage: 1.1+ MB
# </div>

# %% [markdown]
# The `lon_lat` column should be split into two columns, but that will have to wait until later.

# %% [markdown]
# __The End__
